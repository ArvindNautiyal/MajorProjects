# %%
import pandas as pd

# %%
data = pd.read_csv('/content/flats&house (1).csv')

# %%
data.shape
# Out:
# (3984, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3984 entries, 0 to 3983
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PROPERTY_NAME    3984 non-null   object
#  1   PROPERTY_TYPE    3984 non-null   object
#  2   SOCIETY          3398 non-null   object
#  3   PRICE            3954 non-null   float64
#  4   PRICE_PER_SQFT   3954 non-null   float64
#  5   AREA             3954 non-null   float64
#  6   AREAWITHTYPE     3984 non-null   object
#  7   BEDROOM          3984 non-null   int64
#  8   BATHROOM         3984 non-null   int64
#  9   BALCONY          3984 non-null   object
#  10  ADDITIONALROOM   3984 non-null   object
#  11  ADDRESS          3973 non-null   object
#  12  FLOORNUM         3982 non-null   float64
#  13  FACING           3984 non-null   object
#  14  AGEPOSSESSION    3983 non-null   object
#  15  NEARBYLOCATIONS  3770 non-null   object
#  16  DESCRIPTION      3984 non-null   object
#  17  FURNISHDETAILS   2943 non-null   object
#  18  FEATURES         3264 non-null   object
#  19  RATING           3533 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 622.6+ KB

# %%
l = []
for i in data.columns:
  l.append(i.lower())

# %%
data.columns = l

# %%
data.sample(3)
# Out:
#                                       property_name property_type  \
# 710                4 BHK Flat in Sector 104 Gurgaon          flat
# 3225  4 Bedroom House for sale in Sector 63 Gurgaon        houses
# 1108                2 BHK Flat in Sector 82 Gurgaon          flat
#
#                      society  price  price_per_sqft    area  \
# 710              ATS Triumph   2.78          8825.0  3150.0
# 3225          dlf the arbour   8.50         21519.0  3950.0
# 1108  Vatika The Seven Lamps   0.78          5932.0  1315.0
#
#                                 areawithtype  bedroom  bathroom balcony  \
# 710   Super Built up area 3150(292.64 sq.m.)        4         4      3+
# 3225      Built Up area: 3950 (366.97 sq.m.)        4         4      3+
# 1108  Super Built up area 1298(120.59 sq.m.)        2         2       2
#
#      additionalroom                                         address  floornum  \
# 710    servant room       N/a, Sector 104 Gurgaon, Gurgaon, Haryana      11.0
# 3225  not available  Sector 63, Sector 63 Gurgaon, Gurgaon, Haryana      27.0
# 1108  not available             Sector 82 Gurgaon, Gurgaon, Haryana       0.0
#
#           facing    agepossession  \
# 710        south  1 to 5 Year Old
# 3225          na        undefined
# 1108  north-west  1 to 5 Year Old
#
#                                         nearbylocations  \
# 710   ['IFFCO Chowk Metro Station', 'The Esplanade M...
# 3225  ['Radhakrishna Shani Mandir', 'pracksht hospit...
# 1108  ['SS Omnia Mall', 'Golf Course Ext Rd', 'Knowl...
#
#                                             description  \
# 710   Located in the popular residential address of ...
# 3225  Best in class property available at sector 63 ...
# 1108  Brokers excuse, 2 bhk, 1298 sq. Ft., east faci...
#
#                                          furnishdetails  \
# 710                                                  []
# 3225  ['1 Wardrobe', '1 Fan', '1 Light', 'No AC', 'N...
# 1108  ['1 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
#
#                                                features  \
# 710   ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3225                                                NaN
# 1108  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
#
#                                                  rating
# 710   ['Green Area4 out of 5', 'Construction5 out of...
# 3225                                                NaN
# 1108  ['Green Area5 out of 5', 'Construction5 out of...

# %%
data.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society             586
# price                30
# price_per_sqft       30
# area                 30
# areawithtype          0
# bedroom               0
# bathroom              0
# balcony               0
# additionalroom        0
# address              11
# floornum              2
# facing                0
# agepossession         1
# nearbylocations     214
# description           0
# furnishdetails     1041
# features            720
# rating              451
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 13

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.insert(loc=3,column='sector',value=data['property_name'].str.split("in").str.get(1).str.replace("Gurgaon"," ").str.strip())

# %%
data.sample(3)
# Out:
#                          property_name property_type         society  \
# 1757   3 BHK Flat in Sector 69 Gurgaon          flat      Tulip Leaf
# 2421  3 BHK Flat in Sector 106 Gurgaon          flat     MRG Skyline
# 2177   1 BHK Flat in Sector 56 Gurgaon          flat  Kendriya Vihar
#
#           sector  price  price_per_sqft    area  \
# 1757   Sector 69   2.07         11423.0  1812.0
# 2421  Sector 106   1.82         13392.0  1359.0
# 2177   Sector 56   0.47          7768.0   605.0
#
#                                            areawithtype  bedroom  bathroom  \
# 1757             Super Built up area 1812(168.34 sq.m.)        3         3
# 2421  Built Up area: 1359 (126.26 sq.m.)Carpet area:...        3         2
# 2177                     Carpet area: 605 (56.21 sq.m.)        1         1
#
#       ... additionalroom                                           address  \
# 1757  ...  not available               Sector 69 Gurgaon, Gurgaon, Haryana
# 2421  ...  not available  Sector 106, Sector 106 Gurgaon, Gurgaon, Haryana
# 2177  ...  not available               Sector 56 Gurgaon, Gurgaon, Haryana
#
#      floornum      facing    agepossession  \
# 1757     16.0  south-west  1 to 5 Year Old
# 2421      4.0        east        undefined
# 2177      3.0          na     10+ Year Old
#
#                                         nearbylocations  \
# 1757  ['Omaxe City Centre Sector 49', 'Southern Peri...
# 2421  ['Chintapurni Mandir', 'State bank ATM', 'R K ...
# 2177  ['Sector metro station', 'Sector metro station...
#
#                                             description  \
# 1757  Looking for a 3 bhk property for sale in gurga...
# 2421  Comming soon sec -106luxury floors just 0 km f...
# 2177  1 bhk property in a well maintained gated soci...
#
#                                          furnishdetails  \
# 1757  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 2421  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 2177  ['1 Wardrobe', '1 Bed', '1 Water Purifier', '2...
#
#                                                features  \
# 1757  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2421                                                NaN
# 2177  ['Power Back-up', 'Maintenance Staff', 'Water ...
#
#                                                  rating
# 1757  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2421                                                NaN
# 2177  ['Green Area5 out of 5', 'Construction4 out of...
#
# [3 rows x 21 columns]

# %%
data['sector'] = data['sector'].str.lower()

# %%
data['sector'].value_counts()
# Out:
# sector
# sohna                 163
# sector 102            113
# sector 85             110
# sector 92             104
# sector 69              94
#                      ...
# near pataudi chowk      1
# pataudi road            1
# lucknow                 1
# part 3 sector 5         1
# khandsa                 1
# Name: count, Length: 302, dtype: int64

# %%
l2 = []
for i in data['sector']:
  if 'sector' not in i:
    l2.append(i)
  else:
    pass

# %%
l2
# Out:
# ['krishna colony',
#  'ashok vihar',
#  'sohna',
#  'dwarka expressway',
#  'sohna',
#  'new palam vihar',
#  'sohna',
#  'sohna',
#  'ashok vihar phase 3 extension',
#  'sohna',
#  'dlf phase 4',
#  'sohna',
#  'block a surya vihar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'laxman vihar',
#  'new palam vihar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'laxman vihar',
#  'dwarka expressway',
#  'sohna',
#  'sohna',
#  'dwarka expressway',
#  'sohna',
#  'sohna',
#  'sushant lok phase 1',
#  'sohna road',
#  'sohna',
#  'ashok vihar phase 2',
#  'rajiv colony',
#  'garauli kalan',
#  'bhawani enclave',
#  'sohna',
#  'iffco chowk',
#  'palam vihar',
#  'dwarka expressway',
#  'gwal pahari',
#  'block a surya vihar',
#  'sohna',
#  'sohna road',
#  'malibu town',
#  'sohna',
#  'sohna',
#  'golf course road',
#  'chakkarpur',
#  'laxman vihar',
#  'sohna',
#  'krishna colony',
#  'ashok vihar phase 2',
#  'palam vihar',
#  'kanahi',
#  'dlf phase 5',
#  'sohna',
#  'nirvana country',
#  'dlf phase 2',
#  'palam vihar',
#  'dlf phase 5',
#  'sohna',
#  'nirvana country',
#  'dlf phase 2',
#  'sohna',
#  'palam vihar',
#  'palam vihar',
#  'dlf phase 4',
#  'dlf phase 2',
#  'gwal pahari',
#  'dlf phase 3',
#  'heritage city',
#  'gwal pahari',
#  'dlf phase 3',
#  'nirvana country',
#  'dwarka expressway',
#  'palam vihar',
#  'palam vihar',
#  'dlf phase 4',
#  'dlf phase 4',
#  'ambience island',
#  'ambience island',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'nirvana country',
#  'suncity',
#  'gwal pahari',
#  'nirvana country',
#  'dlf phase 3',
#  'dlf phase 4',
#  'dlf phase 4',
#  'gwal pahari',
#  'sai kunj',
#  'manesar',
#  'dlf phase 5',
#  'nirvana country',
#  'sushant lok phase 1',
#  'dlf phase 4',
#  'sohna',
#  'sohna',
#  'palam vihar',
#  'palam vihar',
#  'dlf phase 5',
#  'palam vihar',
#  'dlf phase 5',
#  'sohna',
#  'sohna',
#  'dlf phase 5',
#  'nirvana country',
#  'dlf phase 4',
#  'dlf phase 5',
#  'nirvana country',
#  'dlf phase 5',
#  'gwal pahari',
#  'nirvana country',
#  'nirvana country',
#  'nirvana country',
#  'nirvana country',
#  'nirvana country',
#  'gwal pahari',
#  'nirvana country',
#  'nirvana country',
#  'sohna',
#  'sohna',
#  'imt manesar',
#  'gwal pahari',
#  'mg road',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'dlf phase 4',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'gwal pahari',
#  'sultanpur',
#  'sushant lok phase 1',
#  'suncity',
#  'mg road',
#  'mg road',
#  'nirvana country',
#  'nirvana country',
#  'nirvana country',
#  'manesar',
#  'nirvana country',
#  'nirvana country',
#  'nirvana country',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'civil l',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'lajpat nagar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'nirvana country',
#  'sohna',
#  'sohna',
#  'new',
#  'dlf phase 5',
#  'sohna',
#  'chakkarpur',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'gwal pahari',
#  'dlf phase 2',
#  'surya vihar',
#  'near pataudi chowk',
#  'dlf phase 5',
#  'gwal pahari',
#  'sohna',
#  'sohna',
#  'sohna',
#  'cyber city',
#  'sohna',
#  'new colony',
#  'subhash nagar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'ats marigold',
#  'sohna',
#  'laxman vihar',
#  'sohna',
#  'gwal pahari',
#  'imt manesar',
#  'malibu town',
#  'palam vihar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'adarsh nagar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sushant lok phase 3',
#  'sohna',
#  'carterpuri village',
#  'gwal pahari',
#  'sohna',
#  'valley view estate',
#  'sohna',
#  'shanti nagar',
#  'sushant lok',
#  'mehrauli   road',
#  'laxman vihar phase 2',
#  'sohna',
#  'faridabad road',
#  'sohna',
#  'sohna',
#  'sohna',
#  'manesar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'chakkarpur',
#  'sushant lok',
#  'sohna',
#  'dayanand colony',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'samaspur',
#  'nirvana country pocket h',
#  'iffco chowk',
#  'ashok vihar phase 2',
#  'patel nagar',
#  'sohna',
#  'dlf phase 5',
#  'gwal pahari',
#  'mehrauli   road',
#  'surat nagar 1',
#  'chakkarpur',
#  'sispal vihar',
#  'golf course ext road',
#  'shankar vihar',
#  'sohna',
#  'sushant lok phase 1',
#  'sohna',
#  'sohna',
#  'new palam vihar phase 2',
#  'dlf phase 4',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'adarsh nagar',
#  'mehrauli   road',
#  'mehrauli   road',
#  'sohna',
#  'samaspur',
#  'ashok vihar phase 2',
#  'sohna',
#  'dlf phase 5',
#  'mehrauli   road',
#  'surat nagar 1',
#  'chakkarpur',
#  'sispal vihar',
#  'sohna',
#  'shankar vihar',
#  'sohna',
#  'sushant lok phase 1',
#  'sohna',
#  'sohna',
#  'dlf phase 4',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sohna',
#  'mehrauli   road',
#  'mehrauli   road',
#  'sohna',
#  'sohna',
#  'sohna',
#  'dlf phase 5',
#  'ashok vihar phase 2',
#  'valley view estate',
#  'sohna',
#  'sohna',
#  'dwarka expressway',
#  'sohna',
#  'sohna',
#  'laxman vihar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'ashok vihar',
#  'bhondsi',
#  'palam vihar extension',
#  'sohna',
#  'sohna',
#  'ashok vihar phase 3 extension',
#  'new',
#  'saroop garden rajendra park',
#  'palam vihar',
#  'dayanand colony',
#  'dwarka expressway',
#  'adarsh nagar',
#  'bptp',
#  'sohna',
#  'palam vihar',
#  'sohna',
#  'new palam vihar',
#  'sohna',
#  'south city 1',
#  'valley view estate',
#  'sohna',
#  'sohna',
#  'laxman vihar',
#  'dayanand colony',
#  'sohna',
#  'sohna road',
#  'valley view estate',
#  'sohna',
#  'new',
#  'shanti nagar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'sushant lok phase 3',
#  'sohna',
#  'ashok vihar',
#  'sohna',
#  'sohna',
#  'sohna',
#  'imt manesar',
#  'dharam colony',
#  'palam vihar',
#  'sohna',
#  'golf course ext road',
#  'new',
#  'dlf phase 4',
#  'adarsh nagar',
#  'rajendra park',
#  'palam vihar',
#  'dharam colony',
#  'dlf phase 4',
#  'dlf phase 3',
#  'sushant lok phase 1',
#  'sushant lok phase 1',
#  'sushant lok phase 1',
#  'dlf phase 1',
#  'dlf phase 2',
#  'sushant lok phase 1',
#  'dlf phase 2',
#  'dlf phase 4',
#  'dlf phase 3',
#  'dlf phase 1',
#  'b block sushant lok phase 1',
#  'new palam vihar phase 1',
#  'dlf phase 2',
#  'nirvana country',
#  'uppals southend',
#  'dlf phase 2',
#  'sushant lok phase 1',
#  'nirvana country',
#  'dlf phase 2',
#  'dlf phase 2',
#  'sushant lok phase 3',
#  'dlf phase 2',
#  'dlf phase 2',
#  'dlf phase 1',
#  'nars',
#  'sushant lok phase 1',
#  'dlf phase 2',
#  'c block sushant lok phase 1',
#  'palam vihar',
#  'palam vihar',
#  'greenwood city',
#  'uppals southend',
#  'c block sushant lok phase 1',
#  'nirvana country',
#  'laxman vihar phase 2',
#  'new colony',
#  'nirvana country',
#  'dlf phase 2',
#  'rajendra park',
#  'laxman vihar phase 2',
#  'laxman vihar phase 2',
#  'laxman vihar phase 2',
#  'laxman vihar phase 2',
#  'laxman vihar phase 2',
#  'laxman vihar phase 2',
#  'sushant lok phase 1',
#  'shivaji nagar',
#  'sushant lok phase 1',
#  'sushant lok phase 1',
#  'nirvana country',
#  'nirvana country',
#  'palam vihar',
#  'dharam colony',
#  'krishna colony',
#  'laxman vihar',
#  'dlf phase 3',
#  'ashok vihar phase 3 extension',
#  'hira nagar',
#  'gopal nagar, garhi ghasita, sonipat',
#  'jat colony,fazilpur/taj nagar road',
#  'south city 1',
#  'kheri',
#  'madanpuri',
#  'dlf phase 3',
#  'sohna road',
#  'dayanand colony',
#  'mohan nagar',
#  'rajendra park',
#  'daulatabad',
#  'ashok vihar phase 3 extension',
#  'vishnu garden',
#  'dlf phase 1',
#  'new basti',
#  'shivaji nagar',
#  'manesar',
#  'new colony',
#  'ashok vihar',
#  'maruti kunj',
#  'laxmi garden',
#  'mohan nagar',
#  'saraswati vihar',
#  'imt manesar',
#  'bhora kalan',
#  'near nand hospital',
#  'dlf phase 1',
#  'shivpuri',
#  'jyoti park',
#  'sohna',
#  'subhash nagar',
#  'new palam vihar',
#  'palam vihar',
#  'surat nagar phase 2',
#  'ashok vihar',
#  'rajendra park',
#  'rajiv nagar',
#  'madanpuri',
#  'new palam vihar phase 1',
#  'arjun nagar',
#  'ashok vihar phase i',
#  'surya vihar',
#  'block h ashok vihar phase iii extension',
#  'dlf phase 1',
#  'devilal colony',
#  'surya vihar',
#  'prem nagar',
#  'bhim nagar',
#  'laxman vihar phase 2',
#  'surat nagar',
#  'gandhi nagar',
#  'khandsa',
#  'ashok vihar phase 3 extension',
#  'ravi nagar',
#  'maruti kunj',
#  'rajendra park',
#  'new palam vihar phase 2',
#  'west rajiv nagar',
#  'ashok vihar phase 3 extension',
#  'surat nagar phase 2',
#  'vishnu garden',
#  'sushant lok phase 3',
#  'near khandsa road',
#  'devilal colony',
#  'sheetla colony',
#  'laxman vihar',
#  'farukhnagar',
#  'ravi nagar',
#  'mianwali colony',
#  'dharam colony',
#  'palam vihar',
#  'sohna',
#  'saraswati vihar',
#  'lucknow',
#  'pataudi road',
#  'surya vihar',
#  'ravi nagar',
#  'subhash nagar',
#  'jyoti park',
#  'dlf phase 2',
#  'malibu town',
#  'c block sushant lok phase 1',
#  'bhim nagar',
#  'jyoti park',
#  'nirvana country',
#  'laxman vihar',
#  'laxman vihar',
#  'laxman vihar',
#  'laxman vihar',
#  'shakti nagar',
#  'baldev nagar',
#  'shivpuri',
#  'new basti',
#  'rajiv nagar',
#  'vishnu garden',
#  'acharya puri',
#  'bhondsi',
#  'arjun nagar',
#  'dlf phase 2',
#  'ashok vihar phase 3 extension',
#  'ashok vihar phase 3 extension',
#  'garhi harsaru',
#  'pratap nagar',
#  'manohar nagar',
#  'laxman vihar',
#  'arjun nagar',
#  'vir nagar',
#  'madanpuri',
#  'bhim nagar',
#  'surat nagar 1',
#  'hno 13 sagar enclave sura',
#  'new palam vihar',
#  'hira nagar',
#  'laxman vihar',
#  'ram nagar',
#  'baldev nagar',
#  'sheetla colony',
#  'pratap nagar',
#  'dlf phase 2',
#  'palam vihar',
#  'sushant lok phase 1',
#  'krishna colony',
#  'rajendra park',
#  'farukhnagar',
#  'laxman vihar',
#  'laxman vihar',
#  'surat nagar 1',
#  'ashok vihar phase 2',
#  'subhash nagar',
#  'sohna road',
#  'dlf phase 4',
#  'om nagar',
#  'bhawani enclave',
#  'garhi harsaru',
#  'saraswati vihar',
#  'jacobpura',
#  'arjun nagar',
#  'faridabad road',
#  'rajendra park',
#  'tekchand nagar',
#  'ashok vihar phase 3',
#  'ansal plaza',
#  'dlf phase 5',
#  "ansal's palam vihar",
#  'devilal colony',
#  'prem nagar',
#  'jacobpura near sadar bazar',
#  'dlf phase 3',
#  'laxman vihar',
#  'prem nagar',
#  'bhim nagar',
#  'manesar',
#  'saraswati vihar',
#  'maruti kunj',
#  'nirvana country',
#  'rajiv nagar',
#  'laxman vihar',
#  'rajendra park',
#  'surat nagar 1',
#  'rajendra park',
#  'devilal colony',
#  'shivji park colony',
#  'patel nagar',
#  'laxmi garden',
#  'ashok vihar phase 2',
#  'rajendra park',
#  'ravi nagar',
#  'laxmi garden',
#  'dlf phase 3',
#  'palam vihar',
#  'laxman vihar',
#  'surat nagar 1',
#  'laxman vihar phase 2',
#  'laxman vihar phase 2',
#  'laxman vihar',
#  'sohna',
#  'dlf phase 2',
#  'rajiv nagar',
#  'mianwali colony',
#  'baldev nagar',
#  'laxman vihar',
#  'rajendra park',
#  'patel nagar',
#  'palam vihar extension',
#  'laxman vihar',
#  'udyog vihar phase 1',
#  'rajendra park',
#  'sheetla colony',
#  'arjun nagar',
#  'laxman vihar phase 2',
#  'madanpuri',
#  'surat nagar',
#  'mahalaxmi garden, rajendra place',
#  'jacobpura',
#  'rajiv nagar',
#  'rattan garden',
#  'mianwali colony',
#  'sadar bazar',
#  'dayanand colony',
#  'naharpur rupa',
#  'dlf phase 3',
#  'laxman vihar',
#  'palam vihar extension',
#  'saraswati vihar',
#  'laxman vihar',
#  'shakti nagar',
#  'dlf phase 3',
#  'laxman vihar, railway road,',
#  'mianwali colony',
#  'dlf phase 4',
#  'palam vihar extension',
#  'rajendra park',
#  'new colony',
#  'damdma',
#  'sohna',
#  'garhi harsaru',
#  'rajendra park',
#  'nirvana country',
#  'ashok vihar phase 3 extension',
#  ', delhi ncr',
#  'new jyoti park',
#  'laxman vihar',
#  'shivaji nagar',
#  'gandhi nagar',
#  'lajpat nagar',
#  'sohna   road',
#  'jacobpura',
#  'mahavir pura',
#  'malibu town',
#  'sohna road',
#  'jacobpura',
#  'garhi harsaru',
#  'bhondsi',
#  'g block dlf city phase 1',
#  'manohar nagar',
#  'palam vihar',
#  'surat nagar',
#  ', delhi ncr',
#  'park view',
#  'shakti nagar',
#  'bhondsi',
#  'new colony',
#  'palam vihar extension',
#  'laxman vihar',
#  'jyoti park',
#  'rajiv nagar',
#  'sohna   road',
#  'vishnu garden',
#  'ashok vihar phase 2',
#  'ashok vihar phase 2',
#  'jyoti park',
#  'dlf phase 2',
#  'dharam colony block e',
#  'subhash nagar',
#  'ravi nager basai road',
#  'begampur khatola',
#  'dhankot',
#  'shivpuri',
#  'c block sushant lok phase 1',
#  'nirvana country',
#  'shivpuri',
#  'gandhi nagar',
#  'sohna road',
#  'jacobpura',
#  'sohna road',
#  'rajiv chowk',
#  'devi lal colony gali no 12 gurgaon nr omkar public school',
#  'dlf phase 1',
#  'ashok vihar',
#  'alipur',
#  'sohna road',
#  'laxman vihar',
#  'dlf phase 3',
#  'dlf phase 3',
#  'sushant lok phase 1',
#  'shivaji nagar',
#  'daulatabad',
#  'dwarka expressway',
#  'palam vihar extension',
#  'new colony',
#  'golf course road',
#  'jacobpura',
#  'rajendra park',
#  'ashok vihar phase 3 extension',
#  'sushant lok phase 1',
#  'c block sushant lok phase 1',
#  'saraswati enclave',
#  'sec 3 bhim vihar part 1 bhimgher kheri',
#  'near euro',
#  'west rajiv nagar',
#  'bhimgarh kheri phase 3',
#  'dlf phase 3',
#  'mianwali colony',
#  'huda saraswati vihar',
#  'acharya puri',
#  'rajiv chowk',
#  'dlf phase 3',
#  'laxman vihar',
#  'new colony',
#  'dlf phase 4',
#  'madanpuri',
#  'dharam colony',
#  'dlf phase 3',
#  'dlf phase 3',
#  'mianwali colony',
#  'palam vihar extension',
#  'sohna road',
#  'uppals southend',
#  'sohna road',
#  'baldev nagar',
#  'ashok vihar phase 3 extension',
#  'sohna road',
#  'dlf phase 1',
#  'laxmna vihar, phase 2',
#  'surat nagar 1',
#  'palam vihar extension',
#  'mianwali colony',
#  'dlf phase 2',
#  'dlf phase 1',
#  'dlf phase 1',
#  'dlf phase 4',
#  'dlf phase 2',
#  'dlf phase 1',
#  'palam vihar',
#  'dlf phase 1',
#  'south city 1',
#  'uppals southend',
#  'nirvana country',
#  'dlf phase 2',
#  'malibu town',
#  'sushant lok phase 2',
#  'dlf phase 1',
#  'dlf phase 2',
#  'ansal plaza',
#  'south city 1',
#  'laxman vihar phase 2',
#  'dlf phase 1',
#  'dlf phase 2',
#  'a block sushant lok phase 1',
#  'ansal plaza',
#  'dlf phase 1',
#  'dlf phase 2',
#  'sushant lok phase 2',
#  'palam vihar',
#  'sushant lok phase 1',
#  'sushant lok phase 1',
#  'sushant lok phase 3',
#  'sushant lok phase 3',
#  'greenwood city',
#  'dlf phase 2',
#  'dlf phase 2',
#  'dlf phase 2',
#  'dlf phase 2',
#  'dlf phase 2',
#  'palam vihar',
#  'dlf phase 1',
#  'dlf phase 1',
#  'dlf phase 1',
#  'nirvana country',
#  'dlf phase 3',
#  'dlf phase 2',
#  'dlf phase 1',
#  'nars',
#  'laxman vihar',
#  'nirvana country',
#  'palam vihar',
#  'palam vihar',
#  'palam vihar',
#  'dlf phase 1',
#  'dlf phase 1',
#  'dlf phase 2',
#  'sushant lok phase 1',
#  'dlf phase 1',
#  'dlf phase 1',
#  'dlf phase 3',
#  'nirvana country',
#  'nirvana country',
#  'south city 1',
#  'ansal plaza',
#  'dlf phase 1',
#  'dlf phase 1',
#  'dlf phase 1',
#  'greenwood city',
#  'greenwood city',
#  'ansal plaza',
#  'dlf phase 1',
#  'palam vihar',
#  'mehrauli   road',
#  'dlf phase 1',
#  'sushant lok phase 3',
#  'sushant lok phase 3',
#  'dlf phase 4',
#  'uppals southend',
#  'uppals southend',
#  'malibu town',
#  'dlf phase 1',
#  'south city 1',
#  'mayfield garden',
#  'palam vihar',
#  'dlf phase 4',
#  'nirvana country',
#  'b block sushant lok phase 1',
#  'palam vihar',
#  'dlf phase 1',
#  'dlf phase 2',
#  'sushant lok phase 3',
#  'sushant lok phase 1',
#  'dlf phase 2',
#  'nirvana country',
#  'nirvana country',
#  'palam vihar',
#  'south city',
#  'nirvana country',
#  'c block sushant lok phase 1',
#  'sushant lok phase 1',
#  'sushant lok phase 3',
#  'sushant lok phase 3',
#  'b block sushant lok phase 1',
#  'dlf phase 4',
#  'sushant lok phase 3',
#  'mayfield garden',
#  'sushant lok phase 1',
#  'greenwood city',
#  'nirvana country',
#  'nirvana country',
#  'sushant lok phase 1',
#  'dlf phase 1',
#  'rosewood',
#  'rosewood',
#  'dlf phase 1',
#  'sushant lok phase 3',
#  'sushant lok phase 2',
#  'sushant lok phase 2',
#  'south city 1',
#  'south city 1',
#  'dlf phase 4',
#  'v block dlf phase 3',
#  'dlf phase 1',
#  'dlf phase 2',
#  'sushant lok phase 1',
#  'ansal plaza',
#  'suncity',
#  'a block sushant lok phase 1',
#  'dlf phase 1',
#  'dlf phase 1',
#  'suncity',
#  'sushant lok phase 3',
#  'dlf phase 1',
#  'palam vihar',
#  'a block sushant lok phase 1',
#  'sushant lok phase 1',
#  'nirvana country',
#  'palam vihar',
#  'palam vihar',
#  'nirvana country',
#  'sushant lok phase 1',
#  'dlf phase 2',
#  'dlf phase 2',
#  'dlf phase 3',
#  'malibu town',
#  'palam vihar',
#  'sushant lok phase 3',
#  'dlf phase 1',
#  'sushant lok phase 1',
#  'dlf phase 1',
#  'c block sushant lok phase 1',
#  'sushant lok phase 1',
#  'dlf phase 2',
#  'dlf phase 4',
#  'dlf phase 3',
#  'nirvana country',
#  'south city 1',
#  'dlf phase 1',
#  'dlf phase 1',
#  'sushant lok phase 1',
#  'sushant lok phase 1',
#  'dlf phase 2',
#  'dlf phase 1',
#  'c block sushant lok phase 1',
#  'dlf phase 3',
#  'nirvana country',
#  'nirvana country',
#  'dlf phase 2',
#  'uppals southend',
#  'uppals southend',
#  'uppals southend',
#  'uppals southend',
#  'dlf phase 2',
#  'uppals southend',
#  'dlf phase 4',
#  'nirvana country',
#  'dlf phase 4',
#  'uppals southend',
#  'nirvana country',
#  'dlf phase 1',
#  'jyoti park',
#  'nirvana country',
#  'dlf phase 2',
#  'dlf phase 1',
#  'dlf phase 4',
#  'nirvana country',
#  'nirvana country',
#  'malibu town',
#  'sushant lok phase 2',
#  'sushant lok phase 3',
#  'bissar',
#  'dlf phase 2',
#  'bissar']

# %%
data['sector'] = data['sector'].str.replace('dharam colony','sector 12')
data['sector'] = data['sector'].str.replace('krishna colony','sector 7')
data['sector'] = data['sector'].str.replace('suncity','sector 54')
data['sector'] = data['sector'].str.replace('prem nagar','sector 13')
data['sector'] = data['sector'].str.replace('mg road','sector 28')
data['sector'] = data['sector'].str.replace('gandhi nagar','sector 28')
data['sector'] = data['sector'].str.replace('laxmi garden','sector 11')
data['sector'] = data['sector'].str.replace('shakti nagar','sector 11')

# %%
data['sector'] = data['sector'].str.replace('baldev nagar','sector 7')
data['sector'] = data['sector'].str.replace('shivpuri','sector 7')
data['sector'] = data['sector'].str.replace('garhi harsaru','sector 17')
data['sector'] = data['sector'].str.replace('imt manesar','manesar')
data['sector'] = data['sector'].str.replace('adarsh nagar','sector 12')
data['sector'] = data['sector'].str.replace('shivaji nagar','sector 11')
data['sector'] = data['sector'].str.replace('bhim nagar','sector 6')
data['sector'] = data['sector'].str.replace('madanpuri','sector 7')

# %%
data['sector'] = data['sector'].str.replace('saraswati vihar','sector 28')
data['sector'] = data['sector'].str.replace('jyoti park','sector 7')
data['sector'] = data['sector'].str.replace('ansal plaza','sector 23')
data['sector'] = data['sector'].str.replace('dayanand colony','sector 6')
data['sector'] = data['sector'].str.replace('sushant lok phase 2','sector 55')
data['sector'] = data['sector'].str.replace('chakkarpur','sector 28')
data['sector'] = data['sector'].str.replace('greenwood city','sector 45')
data['sector'] = data['sector'].str.replace('subhash nagar','sector 12')
data['sector'] = data['sector'].str.replace('mehrauli road','sector 14')

# %%
data['sector'] = data['sector'].str.replace('arjun nagar','sector 8')
data['sector'] = data['sector'].str.replace('ravi nagar','sector 9')
data['sector'] = data['sector'].str.replace('vishnu garden','sector 105')
data['sector'] = data['sector'].str.replace('bhondsi','sector 11')
data['sector'] = data['sector'].str.replace('surya vihar','sector 21')
data['sector'] = data['sector'].str.replace('devilal colony','sector 9')
data['sector'] = data['sector'].str.replace('valley view estate','gwal pahari')

# %%
data['sector'] = data['sector'].str.replace('sohna road road','sohna road')
data['sector'] = data['sector'].str.replace('malibu town','sector 47')
data['sector'] = data['sector'].str.replace('surat nagar 1','sector 104')
data['sector'] = data['sector'].str.replace('new colony','sector 7')
data['sector'] = data['sector'].str.replace('mianwali colony','sector 12')
data['sector'] = data['sector'].str.replace('jacobpura','sector 12')
data['sector'] = data['sector'].str.replace('rajiv nagar','sector 13')
data['sector'] = data['sector'].str.replace('ashok vihar','sector 3')

# %%
data['sector'] = data['sector'].str.replace('dlf phase 1','sector 26')
data['sector'] = data['sector'].str.replace('nirvana country','sector 50')
data['sector'] = data['sector'].str.replace('palam vihar','sector 2')
data['sector'] = data['sector'].str.replace('dlf phase 2','sector 25')
data['sector'] = data['sector'].str.replace('sushant lok phase 1','sector 43')
data['sector'] = data['sector'].str.replace('laxman vihar','sector 4')
data['sector'] = data['sector'].str.replace('dlf phase 4','sector 28')
data['sector'] = data['sector'].str.replace('dlf phase 3','sector 24')

# %%
data['sector'] = data['sector'].str.replace('sushant lok phase 3','sector 57')
data['sector'] = data['sector'].str.replace('dlf phase 5','sector 43')
data['sector'] = data['sector'].str.replace('rajendra park','sector 105')
data['sector'] = data['sector'].str.replace('uppals southend','sector 49')
data['sector'] = data['sector'].str.replace('sohna','sohna road')
data['sector'] = data['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
data['sector'] = data['sector'].str.replace('south city 1','sector 41')
data['sector'] = data['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
data['sector'].value_counts()
# Out:
# sector
# sohna road                              163
# sector 102                              113
# sector 85                               110
# sector 92                               104
# sector 69                                94
#                                        ...
# sector 7, sector 7                        1
# urban estate, sector 5                    1
# khandsa                                   1
# block h sector 3 phase iii extension      1
# hno 13 sagar enclave sura                 1
# Name: count, Length: 252, dtype: int64

# %%
a = data['sector'].value_counts()[data['sector'].value_counts()>=3]

# %%
data = data[data['sector'].isin(a.index)]

# %%
data.shape
# Out:
# (3816, 21)

# %%
data['sector'] = data['sector'].str.replace('sector 95a','sector 95')
data['sector'] = data['sector'].str.replace('sector 23a','sector 23')
data['sector'] = data['sector'].str.replace('sector 12a','sector 12')
data['sector'] = data['sector'].str.replace('sector 3a','sector 3')
data['sector'] = data['sector'].str.replace('sector 110 a','sector 110')
data['sector'] = data['sector'].str.replace('patel nagar','sector 15')
data['sector'] = data['sector'].str.replace('a block sector 43','sector 43')
data['sector'] = data['sector'].str.replace('maruti kunj','sector 12')
data['sector'] = data['sector'].str.replace('b block sector 43','sector 43')
data['sector'] = data['sector'].str.replace('sector-33 sohna road','sector 33')
data['sector'] = data['sector'].str.replace('sector manesar','manesar')
data['sector'] = data['sector'].str.replace('sector 4 phase 2','sector 4')
data['sector'] = data['sector'].str.replace('sector 1a manesar','manesar')
data['sector'] = data['sector'].str.replace('c block sector 43','sector 43')
data['sector'] = data['sector'].str.replace('sector 89 a','sector 89')
data['sector'] = data['sector'].str.replace('sector 2 extension','sector 2')
data['sector'] = data['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
data = data[data['sector']!='new']

# %%
data[data['sector']=='new']
# Out:
# Empty DataFrame
# Columns: [property_name, property_type, society, sector, price, price_per_sqft, area, areawithtype, bedroom, bathroom, balcony, additionalroom, address, floornum, facing, agepossession, nearbylocations, description, furnishdetails, features, rating]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.shape
# Out:
# (3812, 21)

# %%
data.loc[955,'sector'] = 'sector 37'
data.loc[2800,'sector'] = 'sector 92'
data.loc[2838,'sector'] = 'sector 90'
data.loc[2857,'sector'] = 'sector 76'

# %%
data = data[data['sector']!='new sector 2']

# %%
data[data['sector']=='new sector 2']
# Out:
# Empty DataFrame
# Columns: [property_name, property_type, society, sector, price, price_per_sqft, area, areawithtype, bedroom, bathroom, balcony, additionalroom, address, floornum, facing, agepossession, nearbylocations, description, furnishdetails, features, rating]
# Index: []
#
# [0 rows x 21 columns]

# %%
data.shape
# Out:
# (3807, 21)

# %%
data.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'

# %%
data.shape
# Out:
# (3807, 21)

# %%
data.sample(3)
# Out:
#                          property_name property_type             society  \
# 1955   2 BHK Flat in Sector 79 Gurgaon          flat         Godrej Aria
# 1248  3 BHK Flat in Sector 37C Gurgaon          flat  Imperia The Esfera
# 2105     3 BHK Flat in Sector-33 Sohna          flat  Godrej Nature Plus
#
#           sector  price  price_per_sqft    area  \
# 1955   sector 79   1.45          9062.0  1600.0
# 1248  sector 37c   0.98          5399.0  1815.0
# 2105   sector 33   1.70         12592.0  1350.0
#
#                                            areawithtype  bedroom  bathroom  \
# 1955  Super Built up area 1495(138.89 sq.m.)Built Up...        2         2
# 1248  Super Built up area 1815(168.62 sq.m.)Carpet a...        3         4
# 2105                   Carpet area: 1350 (125.42 sq.m.)        3         3
#
#       ...       additionalroom                               address floornum  \
# 1955  ...           study room   Sector 79 Gurgaon, Gurgaon, Haryana      9.0
# 1248  ...  servant room,others  Sector 37C Gurgaon, Gurgaon, Haryana      9.0
# 2105  ...         servant room     Sector-33 Sohna, Gurgaon, Haryana      6.0
#
#           facing    agepossession  \
# 1955        east  1 to 5 Year Old
# 1248  south-west  1 to 5 Year Old
# 2105          na  Within 6 months
#
#                                         nearbylocations  \
# 1955  ['Sapphire 83 Mall', 'Delhi Jaipur Expressway'...
# 1248  ['Approved Sector 37 Mero Station', 'Esplanade...
# 2105  ['Signature Global Infinity Mall Sohna', 'Bads...
#
#                                             description furnishdetails  \
# 1955  This east facing plc location 2.5 bhk apartmen...            NaN
# 1248  Looking for a 3 bhk property for sale in gurga...            NaN
# 2105  Located in the popular residential address of ...            NaN
#
#                                                features  \
# 1955  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1248  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 2105  ['Power Back-up', 'Intercom Facility', 'Lift(s...
#
#                                                  rating
# 1955  ['Green Area4 out of 5', 'Construction5 out of...
# 1248  ['Environment5 out of 5', 'Lifestyle4 out of 5...
# 2105                                                NaN
#
# [3 rows x 21 columns]

# %%
data.columns
# Out:
# Index(['property_name', 'property_type', 'society', 'sector', 'price',
#        'price_per_sqft', 'area', 'areawithtype', 'bedroom', 'bathroom',
#        'balcony', 'additionalroom', 'address', 'floornum', 'facing',
#        'agepossession', 'nearbylocations', 'description', 'furnishdetails',
#        'features', 'rating'],
#       dtype='object')

# %%
data.drop(columns=['property_name','address','description','rating'],inplace=True)

# %%
data.sample(2)
# Out:
#     property_type              society      sector  price  price_per_sqft  \
# 830          flat           ATS Kocoon  sector 109   1.70          9742.0
# 500          flat  Experion Windchants  sector 112   5.31         11204.0
#
#        area                                       areawithtype  bedroom  \
# 830  1745.0  Super Built up area 1745(162.12 sq.m.)Built Up...        3
# 500  4739.0  Super Built up area 4739(440.27 sq.m.)Built Up...        4
#
#      bathroom balcony           additionalroom  floornum facing  \
# 830         3       3            not available      21.0   west
# 500         6      3+  pooja room,servant room      15.0  south
#
#         agepossession                                    nearbylocations  \
# 830  5 to 10 Year Old  ['Jagdish Super Market', 'Dwarka', 'Euro Inter...
# 500   1 to 5 Year Old  ['Ansal Plaza', 'Dwaraka Expressway', 'First S...
#
#                                         furnishdetails  \
# 830                                                NaN
# 500  ['7 AC', 'No Bed', 'No Chimney', 'No Curtains'...
#
#                                               features
# 830  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 500  ['Power Back-up', 'Feng Shui / Vaastu Complian...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data.shape
# Out:
# (3807, 17)

# %%
data.to_csv('/content/final.csv',index=False)
