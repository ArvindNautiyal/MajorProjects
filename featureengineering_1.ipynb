# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv('/content/final-cleaned-dataset.csv')

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data.shape
# Out:
# (3807, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3807 entries, 0 to 3806
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_type    3807 non-null   object
#  1   society          3307 non-null   object
#  2   sector           3807 non-null   object
#  3   price            3780 non-null   float64
#  4   price_per_sqft   3780 non-null   float64
#  5   area             3780 non-null   float64
#  6   areawithtype     3807 non-null   object
#  7   bedroom          3807 non-null   int64
#  8   bathroom         3807 non-null   int64
#  9   balcony          3807 non-null   object
#  10  additionalroom   3807 non-null   object
#  11  floornum         3805 non-null   float64
#  12  facing           3807 non-null   object
#  13  agepossession    3806 non-null   object
#  14  nearbylocations  3622 non-null   object
#  15  furnishdetails   2821 non-null   object
# ...

# %%
data.describe()
# Out:
#              price  price_per_sqft           area      bedroom     bathroom  \
# count  3780.000000     3780.000000    3780.000000  3807.000000  3807.000000
# mean      2.507732    13822.900529    2847.883069     3.343315     3.409246
# std       2.951106    23085.671833   22798.325303     1.879885     1.933905
# min       0.075000        4.000000      50.000000     1.000000     1.000000
# 25%       0.940000     6812.000000    1224.000000     2.000000     2.000000
# 50%       1.500000     9001.000000    1725.000000     3.000000     3.000000
# 75%       2.700000    13769.000000    2295.000000     4.000000     4.000000
# max      31.500000   600000.000000  875000.000000    21.000000    21.000000
#
#           floornum
# count  3805.000000
# mean      6.773456
# std       6.030564
# min       0.000000
# 25%       2.000000
# 50%       5.000000
# 75%      10.000000
# max      51.000000

# %%
data.sample(2)
# Out:
#      property_type             society     sector  price  price_per_sqft  \
# 317           flat      Ansal Heights   sector 86    1.3          4666.0
# 2913          flat  Chanderlok Society  sector 28    0.9          7234.0
#
#         area                            areawithtype  bedroom  bathroom  \
# 317   2786.0  Super Built up area 2786(258.83 sq.m.)        4         6
# 2913  1244.0        Carpet area: 1244 (115.57 sq.m.)        4         2
#
#      balcony       additionalroom  floornum facing    agepossession  \
# 317        2  servant room,others      11.0   east  0 to 1 Year Old
# 2913      3+        not available       1.0     na     10+ Year Old
#
# ...

# %%
data.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'additionalroom',
#        'floornum', 'facing', 'agepossession', 'nearbylocations',
#        'furnishdetails', 'features'],
#       dtype='object')

# %% [markdown]
# Area With Type

# %%
data[['area','areawithtype']].sample(3)
# Out:
#         area  \
# 2737   587.0
# 709   1550.0
# 2011  1366.0
#
#                                                                     areawithtype
# 2737                                              Carpet area: 587 (54.53 sq.m.)
# 709   Super Built up area 1550(144 sq.m.)Carpet area: 1200 sq.ft. (111.48 sq.m.)
# 2011                                      Super Built up area 1366(126.91 sq.m.)

# %% [markdown]
# Carpet Area: The actual usable area within the walls of the apartment where you can lay a carpet. It excludes the thickness of the inner walls.
#
# Built-up Area: The carpet area plus the thickness of the inner walls and the balcony.
#
# Super Built-up Area: The built-up area plus the proportionate share of common areas such as the lobby, staircase, elevator, etc.

# %%
def get_super_built_up_area(text):
  match = re.search(r'Super Built up area (\d+\.?\d*)',text)
  if match:
    return float(match.group(1))
  return None

# %%
def get_area(text,area_type):
  match = re.search(area_type + r'\s*:\s*(\d+\.?\d*)',text)
  if match:
    return float(match.group(1))
  return None

# %%
def convert_to_sqft(text,area_value):
  if area_value is None:
    return None
  match = re.search(r'{} \((\d+\.?\d*) sq.m.\)'.format(area_value),text)
  if match:
    sq_m_value = float(match.group(1))
    return sq_m_value * 10.7639
  return area_value

# %%
data['super_built_up_area'] = data['areawithtype'].apply(get_super_built_up_area)
data['super_built_up_area'] = data.apply(lambda x : convert_to_sqft(x['areawithtype'],x['super_built_up_area']),axis=1)

# %%
data['built_up_area'] = data['areawithtype'].apply(lambda x: get_area(x,'Built Up area'))
data['built_up_area'] = data.apply(lambda x : convert_to_sqft(x['areawithtype'],x['built_up_area']),axis=1)

# %%
data['carpet_area'] = data['areawithtype'].apply(lambda x: get_area(x,'Carpet area'))
data['carpet_area'] = data.apply(lambda x : convert_to_sqft(x['areawithtype'],x['carpet_area']),axis=1)

# %%
data[['price','super_built_up_area','built_up_area','carpet_area']].sample(3)
# Out:
#       price  super_built_up_area  built_up_area  carpet_area
# 1812   3.50               2201.0         2200.0       1800.0
# 3776  11.75                  NaN            NaN          NaN
# 2546   2.30               2585.0            NaN          NaN

# %%
data.isnull().sum()
# Out:
# property_type             0
# society                 500
# sector                    0
# price                    27
# price_per_sqft           27
# area                     27
# areawithtype              0
# bedroom                   0
# bathroom                  0
# balcony                   0
# additionalroom            0
# floornum                  2
# facing                    0
# agepossession             1
# nearbylocations         185
# furnishdetails          986
# features                643
# super_built_up_area    1894
# built_up_area          2614
# carpet_area            1865
# dtype: int64

# %%
plot_values = data[(data['super_built_up_area'].isnull()) & (data['built_up_area'].isnull())& (data['carpet_area'].isnull())]

# %%
plot_values[['price','super_built_up_area','built_up_area','carpet_area']].sample(5)
# Out:
#       price  super_built_up_area  built_up_area  carpet_area
# 3093   7.25                  NaN            NaN          NaN
# 3429   8.10                  NaN            NaN          NaN
# 3612   3.40                  NaN            NaN          NaN
# 3416  12.50                  NaN            NaN          NaN
# 3734   9.90                  NaN            NaN          NaN

# %%
plot_values_index = plot_values.reset_index()

# %%
plot_values_index = plot_values_index['index']

# %%
plot_values_index.sample(2)
# Out:
# 536    3794
# 90     3038
# Name: index, dtype: int64

# %%
def get_plot_area(area_with_type):
  match = re.search(r'Plot area (\d+\.?\d+)',area_with_type)
  if match:
    return float(match.group(1))
  else:
    None

# %%
plot_values['built_up_area'] = plot_values['areawithtype'].apply(get_plot_area)
# Out:
# <ipython-input-523-d8710d559260>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_values['built_up_area'] = plot_values['areawithtype'].apply(get_plot_area)

# %%
plot_values.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'additionalroom',
#        'floornum', 'facing', 'agepossession', 'nearbylocations',
#        'furnishdetails', 'features', 'super_built_up_area', 'built_up_area',
#        'carpet_area'],
#       dtype='object')

# %%
plot_values[['price','super_built_up_area','built_up_area','carpet_area']].sample(4)
# Out:
#       price  super_built_up_area  built_up_area  carpet_area
# 3187    3.3                  NaN          138.0          NaN
# 3616    8.5                  NaN          300.0          NaN
# 3041    6.0                  NaN          270.0          NaN
# 3674    8.0                  NaN         7000.0          NaN

# %%
def convert_scale(x):
  if np.isnan(x['area']) or np.isnan(x['built_up_area']):
    return x['built_up_area']
  else:
      if round(x['area']/x['built_up_area']) == 9.0:
        return x['built_up_area'] * 9
      elif round(x['area']/x['built_up_area']) == 11.0:
        return x['built_up_area'] * 10.7
      else:
        return x['built_up_area']

# %%
plot_values['built_up_area'] = plot_values.apply(convert_scale,axis=1)
# Out:
# <ipython-input-527-c0838a682f07>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_values['built_up_area'] = plot_values.apply(convert_scale,axis=1)

# %%
plot_values.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'additionalroom',
#        'floornum', 'facing', 'agepossession', 'nearbylocations',
#        'furnishdetails', 'features', 'super_built_up_area', 'built_up_area',
#        'carpet_area'],
#       dtype='object')

# %%
plot_values =  plot_values[['price','property_type','area','areawithtype','super_built_up_area', 'built_up_area',
       'carpet_area']]

# %%
plot_values.sample(10)
# Out:
#       price property_type    area                  areawithtype  \
# 3506   2.75        houses  1557.0   Plot area 173(144.65 sq.m.)
# 3693   5.00        houses  2340.0   Plot area 260(217.39 sq.m.)
# 3285   1.44        houses   540.0     Plot area 60(50.17 sq.m.)
# 3054   5.70        houses  5400.0   Plot area 600(501.68 sq.m.)
# 3716   3.75        houses   160.0    Plot area 160(14.86 sq.m.)
# 3380   0.65        houses   500.0    Plot area 500(46.45 sq.m.)
# 3453   6.50        houses  1800.0   Plot area 200(167.23 sq.m.)
# 3550   4.60        houses  2610.0   Plot area 290(242.48 sq.m.)
# 3700   2.20        houses  3200.0  Plot area 3200(297.29 sq.m.)
# 3695   1.15        houses   275.0    Plot area 275(25.55 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 3506                  NaN         1557.0          NaN
# 3693                  NaN         2340.0          NaN
# 3285                  NaN          540.0          NaN
# ...

# %%
plot_values.head()
# Out:
#       price property_type    area                 areawithtype  \
# 2936   5.25        houses  2610.0  Plot area 290(242.48 sq.m.)
# 2937   2.10        houses   549.0       Plot area 61(51 sq.m.)
# 2938   5.00        houses  1161.0  Plot area 129(107.86 sq.m.)
# 2939   3.00        houses   558.0    Plot area 62(51.84 sq.m.)
# 2940   4.50        houses  1152.0  Plot area 128(107.02 sq.m.)
#
#       super_built_up_area  built_up_area  carpet_area
# 2936                  NaN         2610.0          NaN
# 2937                  NaN          549.0          NaN
# 2938                  NaN         1161.0          NaN
# 2939                  NaN          558.0          NaN
# 2940                  NaN         1152.0          NaN

# %%
data.update(plot_values)

# %%
data.isnull().sum()
# Out:
# property_type             0
# society                 500
# sector                    0
# price                    27
# price_per_sqft           27
# area                     27
# areawithtype              0
# bedroom                   0
# bathroom                  0
# balcony                   0
# additionalroom            0
# floornum                  2
# facing                    0
# agepossession             1
# nearbylocations         185
# furnishdetails          986
# features                643
# super_built_up_area    1894
# built_up_area          2067
# carpet_area            1865
# dtype: int64

# %%
data[['price','super_built_up_area','built_up_area','carpet_area']].sample(4)
# Out:
#       price  super_built_up_area  built_up_area  carpet_area
# 2060   1.20                  NaN         1100.0          NaN
# 1431   0.54                  NaN            NaN        845.0
# 697    1.90               1381.0            NaN          NaN
# 806    1.30               1568.0            NaN          NaN

# %% [markdown]
# Additional room
# Types - servant room , store room , study room , pooja room , others room

# %%
data.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'additionalroom',
#        'floornum', 'facing', 'agepossession', 'nearbylocations',
#        'furnishdetails', 'features', 'super_built_up_area', 'built_up_area',
#        'carpet_area'],
#       dtype='object')

# %%
data['additionalroom'].value_counts()
# Out:
# additionalroom
# not available                                    1594
# servant room                                      705
# study room                                        250
# others                                            224
# pooja room                                        164
# store room                                         99
# study room,servant room                            98
# pooja room,servant room                            82
# pooja room,study room,servant room,store room      72
# servant room,others                                60
# pooja room,study room,servant room                 55
# pooja room,study room,servant room,others          54
# servant room,pooja room                            38
# servant room,store room                            33
# study room,others                                  29
# pooja room,study room                              22
# pooja room,others                                  17
# ...

# %%
data['additionalroom'].isnull().sum()
# Out:
# 0

# %%
data['additionalroom'].sample(5)
# Out:
# 1888    not available
# 2787    not available
# 580            others
# 894            others
# 3574       pooja room
# Name: additionalroom, dtype: object

# %%
pattern1 = r'\bstudy room\b'
pattern2 = r'\bstore room\b'
pattern3 = r'\bpooja room\b'
pattern4 = r'\bservant room\b'
pattern5 = r'\bothers\b'
pattern6 = r'\bnot available\b'

# %%
def get_study_room(room):
  match = re.search(pattern1, room)
  if match:
    return int(1)
  else:
    return int(0)

# %%
def get_store_room(room):
  match = re.search(pattern2, room)
  if match:
    return int(1)
  else:
    return int(0)

# %%
def get_pooja_room(room):
  match = re.search(pattern3, room)
  if match:
    return int(1)
  else:
    return int(0)

# %%
def get_servant_room(room):
  match = re.search(pattern4, room)
  if match:
    return int(1)
  else:
    return int(0)

# %%
def get_others_room(room):
  match = re.search(pattern5, room)
  if match:
    return int(1)
  else:
    return int(0)

# %%
def get_na_room(room):
  match = re.search(pattern6, room)
  if match:
    return int(0)
  else:
    return int(0)

# %%
data['study_room'] = data['additionalroom'].apply(get_study_room)

# %%
data['store_room'] = data['additionalroom'].apply(get_store_room)

# %%
data['others_room'] = data['additionalroom'].apply(get_others_room)
data['pooja_room'] = data['additionalroom'].apply(get_pooja_room)
data['na_room'] = data['additionalroom'].apply(get_na_room)
data['servant_room'] = data['additionalroom'].apply(get_servant_room)

# %%
data[['property_type','study_room','store_room','others_room','pooja_room','na_room','servant_room','additionalroom']].head()
# Out:
#   property_type  study_room  store_room  others_room  pooja_room  na_room  \
# 0          flat           0           0            0           0        0
# 1          flat           0           0            0           0        0
# 2          flat           0           0            0           0        0
# 3          flat           1           0            0           0        0
# 4          flat           1           0            0           0        0
#
#    servant_room additionalroom
# 0             0  not available
# 1             0  not available
# 2             0  not available
# 3             0     study room
# 4             0     study room

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3807 entries, 0 to 3806
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3807 non-null   object
#  1   society              3307 non-null   object
#  2   sector               3807 non-null   object
#  3   price                3780 non-null   float64
#  4   price_per_sqft       3780 non-null   float64
#  5   area                 3780 non-null   float64
#  6   areawithtype         3807 non-null   object
#  7   bedroom              3807 non-null   int64
#  8   bathroom             3807 non-null   int64
#  9   balcony              3807 non-null   object
#  10  additionalroom       3807 non-null   object
#  11  floornum             3805 non-null   float64
#  12  facing               3807 non-null   object
#  13  agepossession        3806 non-null   object
#  14  nearbylocations      3622 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'additionalroom',
#        'floornum', 'facing', 'agepossession', 'nearbylocations',
#        'furnishdetails', 'features', 'super_built_up_area', 'built_up_area',
#        'carpet_area', 'study_room', 'store_room', 'others_room', 'pooja_room',
#        'na_room', 'servant_room'],
#       dtype='object')

# %% [markdown]
# Age Possesion

# %%
data['agepossession'].isnull().sum()
# Out:
# 1

# %%
data['agepossession'].value_counts()
# Out:
# agepossession
# 1 to 5 Year Old       1673
# 5 to 10 Year Old       575
# 0 to 1 Year Old        531
# undefined              340
# 10+ Year Old           310
# Under Construction      89
# Within 6 months         70
# Within 3 months         26
# Dec 2023                22
# By 2023                 19
# By 2024                 17
# Dec 2024                16
# Mar 2024                14
# Jan 2024                 8
# Oct 2024                 8
# Dec 2025                 7
# Jun 2024                 7
# Aug 2023                 7
# Nov 2023                 5
# Aug 2024                 4
# By 2025                  4
# Sep 2023                 4
# Jul 2024                 4
# Oct 2023                 4
# Jan 2025                 3
# Feb 2024                 3
# Nov 2024                 3
# May 2024                 3
# Jan 2026                 2
# Jul 2025                 2
# Sep 2025                 2
# Mar 2025                 2
# Oct 2025                 2
# ...

# %%
def categorized_values(value):
  if pd.isna(value):
    return 'undefined'
  if '0 and 1 Year Old' in value or 'Within 6 months' in value or 'Within 3 months' in value:
    return 'new property'
  if '1 to 5 Year Old' in value:
    return 'relatively new property'
  if '5 to 10 Year Old' in value:
    return 'moderately old property'
  if '10+ Year Old' in value:
    return 'old propety'
  if 'Under Construction' in value or 'By' in value:
    return 'under construction property'
  try:
    int(value.split(" ")[-1])
    return 'under construction property'
  except:
    return 'undefined'

# %%
data['agepossession'] = data['agepossession'].apply(categorized_values)

# %%
data[['property_type','agepossession']].sample(3)
# Out:
#      property_type            agepossession
# 1082          flat                undefined
# 996           flat  relatively new property
# 1390          flat                undefined

# %%
data.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'additionalroom',
#        'floornum', 'facing', 'agepossession', 'nearbylocations',
#        'furnishdetails', 'features', 'super_built_up_area', 'built_up_area',
#        'carpet_area', 'study_room', 'store_room', 'others_room', 'pooja_room',
#        'na_room', 'servant_room'],
#       dtype='object')

# %%
data['agepossession'].value_counts()
# Out:
# agepossession
# relatively new property        1673
# undefined                       872
# moderately old property         575
# old propety                     310
# under construction property     281
# new property                     96
# Name: count, dtype: int64

# %% [markdown]
# Furnish Details

# %%
data['furnishdetails'].isnull().sum()
# Out:
# 986

# %%
data['furnishdetails'].value_counts()
# Out:
# furnishdetails
# []                                                                                                                                                                                                                                                                       418
# ['1 Light', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Fan', 'No Geyser', 'No Modular Kitchen', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']     201
# ['1 Modular Kitchen', 'No AC', 'No Bed', 'No Chimney', 'No Curtains', 'No Dining Table', 'No Exhaust Fan', 'No Fan', 'No Geyser', 'No Light', 'No Microwave', 'No Fridge', 'No Sofa', 'No Stove', 'No TV', 'No Wardrobe', 'No Washing Machine', 'No Water Purifier']      72
# ...

# %%
data.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'additionalroom',
#        'floornum', 'facing', 'agepossession', 'nearbylocations',
#        'furnishdetails', 'features', 'super_built_up_area', 'built_up_area',
#        'carpet_area', 'study_room', 'store_room', 'others_room', 'pooja_room',
#        'na_room', 'servant_room'],
#       dtype='object')

# %%
all_furnishings = []
for detail in data['furnishdetails'].dropna():
    furnishings = detail.replace('[', '').replace(']', '').replace("'", "").split(', ')
    all_furnishings.extend(furnishings)
unique_furnishings = list(set(all_furnishings))

def get_furnishing_count(details, furnishing):
    if isinstance(details, str):
        if f"No {furnishing}" in details:
            return 0
        pattern = re.compile(f"(\d+) {furnishing}")
        match = pattern.search(details)
        if match:
            return int(match.group(1))
        elif furnishing in details:
            return 1
    return 0
columns_to_include = [re.sub(r'No |\d+', '', furnishing).strip() for furnishing in unique_furnishings]
columns_to_include = list(set(columns_to_include))
columns_to_include = [furnishing for furnishing in columns_to_include if furnishing]

for furnishing in columns_to_include:
    data[furnishing] = data['furnishdetails'].apply(lambda x: get_furnishing_count(x, furnishing))

furnishings_df = data[['furnishdetails'] + columns_to_include]

# %%
furnishings_df.drop(columns=['furnishdetails'],inplace=True)
# Out:
# <ipython-input-563-52cc1c95c212>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   furnishings_df.drop(columns=['furnishdetails'],inplace=True)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(furnishings_df)

# %%
wcss_reduced = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(scaled_data)
    wcss_reduced.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
n_clusters = 3

# Fit the KMeans model
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(scaled_data)

# Predict the cluster assignments for each row
cluster_assignmendfts = kmeans.predict(scaled_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df = data.iloc[:,:-18]

# %%
df['furnishing_type'] = cluster_assignments

# %%
df.shape
# Out:
# (3807, 27)

# %% [markdown]
# Features

# %%
df['features'].sample(4)
# Out:
# 1240                                                                                                                                                                              ['Feng Shui / Vaastu Compliant', 'Lift(s)', 'High Ceiling Height', 'Maintenance Staff', 'Water Storage', 'Separate entry for servant room', 'Visitor Parking', 'Swimming Pool', 'Park', 'Security Personnel', 'Internet/wi-fi connectivity', 'Shopping Centre', 'Club house / Community Center', 'Water softening plant']
# 2391                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NaN
# ...

# %%
df.shape
# Out:
# (3807, 27)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'additionalroom',
#        'floornum', 'facing', 'agepossession', 'nearbylocations',
#        'furnishdetails', 'features', 'super_built_up_area', 'built_up_area',
#        'carpet_area', 'study_room', 'store_room', 'others_room', 'pooja_room',
#        'na_room', 'servant_room', 'furnishing_type'],
#       dtype='object')

# %%
df['furnishing_type'].sample(3)
# Out:
# 1648    2
# 634     1
# 984     2
# Name: furnishing_type, dtype: int32
