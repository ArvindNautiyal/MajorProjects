# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
data1 = pd.read_csv('/independent-house - independent-house.csv')

# %%
data1.sample(2)
# Out:
#                                     property_name  \
# 384   3 Bedroom House for sale in New Palam Vihar
# 1017  6 Bedroom House for sale in Uppals Southend
#
#                                                    link              society  \
# 384   https://www.99acres.com/3-bhk-bedroom-independ...                  NaN
# 1017  https://www.99acres.com/6-bhk-bedroom-independ...  Uppal Southend4.0 ★
#
#            price             rate                       area  \
# 384      1 Crore   ₹ 8,796/sq.ft.      (100 sq.m.) Plot Area
# 1017  3.75 Crore  ₹ 25,562/sq.ft.  (136 sq.m.) Built-up Area
#
#                                            areaWithType     bedRoom  \
# 384   Plot area 120(100.34 sq.m.)Built Up area: 120 ...  3 Bedrooms
# 1017                  Built Up area: 163 (136.29 sq.m.)  6 Bedrooms
#
#          bathroom       balcony additionalRoom  \
# 384   2 Bathrooms   2 Balconies     Pooja Room
# 1017  6 Bathrooms  3+ Balconies     Study Room
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    1095 non-null   object
#  1   link             1095 non-null   object
#  2   society          471 non-null    object
#  3   price            968 non-null    object
#  4   rate             1054 non-null   object
#  5   area             1095 non-null   object
#  6   areaWithType     987 non-null    object
#  7   bedRoom          987 non-null    object
#  8   bathroom         987 non-null    object
#  9   balcony          987 non-null    object
#  10  additionalRoom   589 non-null    object
#  11  address          1031 non-null   object
#  12  noOfFloor        967 non-null    object
#  13  facing           674 non-null    object
#  14  agePossession    987 non-null    object
#  15  nearbyLocations  913 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# property_name        0
# link                 0
# society            624
# price              127
# rate                41
# area                 0
# areaWithType       108
# bedRoom            108
# bathroom           108
# balcony            108
# additionalRoom     506
# address             64
# noOfFloor          128
# facing             421
# agePossession      108
# nearbyLocations    182
# description         59
# furnishDetails     352
# features           421
# rating             188
# property_id         59
# dtype: int64

# %%
data1.duplicated().sum()
# Out:
# 13

# %%
data1.columns
# Out:
# Index(['property_name', 'link', 'society', 'price', 'rate', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'additionalRoom',
#        'address', 'noOfFloor', 'facing', 'agePossession', 'nearbyLocations',
#        'description', 'furnishDetails', 'features', 'rating', 'property_id'],
#       dtype='object')

# %%
data1.drop(columns=['link','property_id'],inplace=True)

# %%
data1.columns
# Out:
# Index(['property_name', 'society', 'price', 'rate', 'area', 'areaWithType',
#        'bedRoom', 'bathroom', 'balcony', 'additionalRoom', 'address',
#        'noOfFloor', 'facing', 'agePossession', 'nearbyLocations',
#        'description', 'furnishDetails', 'features', 'rating'],
#       dtype='object')

# %%
l = []
for i in data1.columns:
  l.append(i.upper())

# %%
data1.columns = l

# %%
data1.sample(2)
# Out:
#                                      PROPERTY_NAME SOCIETY       PRICE  \
# 373  4 Bedroom House for sale in Sector 52 Gurgaon     NaN         NaN
# 251  8 Bedroom House for sale in Sector 56 Gurgaon     NaN  7.25 Crore
#
#                 RATE                       AREA                 AREAWITHTYPE  \
# 373              NaN  (201 sq.m.) Built-up Area                          NaN
# 251  ₹ 29,336/sq.ft.      (253 sq.m.) Plot Area  Plot area 303(253.35 sq.m.)
#
#         BEDROOM     BATHROOM       BALCONY ADDITIONALROOM  \
# 373         NaN          NaN           NaN            NaN
# 251  8 Bedrooms  8 Bathrooms  3+ Balconies            NaN
#
#                                  ADDRESS NOOFFLOOR      FACING  \
# 373                                  NaN       NaN         NaN
# 251  Sector 56 Gurgaon, Gurgaon, Haryana  0 Floors  North-East
#
#         AGEPOSSESSION                                    NEARBYLOCATIONS  \
# ...

# %%
data1['SOCIETY'].value_counts()
# Out:
# SOCIETY
# Vipul Tatvam Villa                                   27
# International City by SOBHA Phase 2                  26
# Emaar MGF Marbella                                   26
# International City by Sobha Phase 1                  23
# Unitech Uniworld Resorts                             14
# DLF City Plots                                       11
# DLF City Plots Phase 2                               11
# Unitech Espace                                       11
# Bptp Visionnaire                                      9
# Eldeco Mansionz                                       9
# Uppal Southend4.0 ★                                   9
# Not Applicable                                        7
# Experion Windchants3.8 ★                              6
# Ansals Palam Vihar                                    6
# Sushant Lok 1 Builder Floors                          6
# DLF New Town Heights 24.0 ★                           5
# DLF City Phase 1                                      5
# ...

# %%
data1['SOCIETY'] = data1['SOCIETY'].astype('str')

# %%
data1.shape
# Out:
# (1095, 19)

# %%
import re
data1['SOCIETY'] = data1['SOCIETY'].apply(lambda x: re.sub(r'\d+(\.\d+)?\s?★',"",str(x)).strip()).str.lower()

# %%
data1['SOCIETY'].value_counts()
# Out:
# SOCIETY
# nan                                                  624
# vipul tatvam villa                                    27
# international city by sobha phase 2                   26
# emaar mgf marbella                                    26
# international city by sobha phase 1                   23
# unitech uniworld resorts                              14
# dlf city plots phase 2                                11
# unitech espace                                        11
# dlf city plots                                        11
# bptp visionnaire                                       9
# uppal southend                                         9
# eldeco mansionz                                        9
# dlf new town heights                                   7
# not applicable                                         7
# experion windchants                                    6
# sushant lok 1 builder floors                           6
# ...

# %%
data1.sample(2)
# Out:
#                                          PROPERTY_NAME SOCIETY       PRICE  \
# 350  6 Bedroom House for sale in Ashok Vihar Phase ...     nan   1.5 Crore
# 859           12 Bedroom House for sale in DLF Phase 1     nan  10.5 Crore
#
#                 RATE                       AREA  \
# 350   ₹ 5,000/sq.ft.  (279 sq.m.) Built-up Area
# 859  ₹ 43,210/sq.ft.      (253 sq.m.) Plot Area
#
#                                           AREAWITHTYPE      BEDROOM  \
# 350                 Built Up area: 3000 (278.71 sq.m.)   6 Bedrooms
# 859  Plot area 302(252.51 sq.m.)Built Up area: 300 ...  12 Bedrooms
#
#          BATHROOM       BALCONY           ADDITIONALROOM  \
# 350    1 Bathroom    No Balcony                      NaN
# 859  12 Bathrooms  3+ Balconies  Servant Room,Pooja Room
#
#                                                ADDRESS NOOFFLOOR      FACING  \
# 350  Ashok Vihar Phase 3 Extension, Ashok Vihar Pha...  1 Floors         NaN
# ...

# %%
data1['PRICE'].value_counts()
# Out:
# PRICE
# 3.5 Crore           19
# 5.5 Crore           17
# 6.5 Crore           16
# 6 Crore             14
# 8 Crore             13
# 5 Crore             13
# 4.5 Crore           13
# 50 Lac              13
# 70 Lac              13
# 75 Lac              13
# 85 Lac              12
# 2.5 Crore           12
# 8.5 Crore           12
# 7 Crore             12
# 4 Crore             11
# 1.5 Crore           11
# 60 Lac              10
# 45 Lac              10
# Price on Request    10
# 90 Lac              10
# 10 Crore            10
# 9 Crore             10
# 2.25 Crore          10
# 80 Lac               9
# 1.7 Crore            9
# 9.5 Crore            9
# 1.1 Crore            9
# 12 Crore             9
# 2 Crore              9
# 1.6 Crore            8
# 4.6 Crore            8
# 1 Crore              8
# 6.75 Crore           8
# 11 Crore             8
# 3.75 Crore           8
# 1.2 Crore            7
# 2.1 Crore            7
# 1.3 Crore            7
# 65 Lac               7
# ...

# %%
data1['PRICE'] = data1['PRICE'].astype('str')

# %%
def convert_to_crore(price):
    if 'Lac' in price:
        return float(price.split()[0]) / 100
    elif 'Crore' in price:
        return float(price.split()[0])
    else:
        return None

data1['PRICE'] = data1['PRICE'].apply(convert_to_crore)

# %%
data1.head(1)
# Out:
#                                     PROPERTY_NAME           SOCIETY  PRICE  \
# 0  5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
#
#               RATE                   AREA                 AREAWITHTYPE  \
# 0  ₹ 20,115/sq.ft.  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
#
#       BEDROOM     BATHROOM       BALCONY ADDITIONALROOM  \
# 0  5 Bedrooms  4 Bathrooms  3+ Balconies   Servant Room
#
#                                      ADDRESS NOOFFLOOR      FACING  \
# 0  29b, Sector 70A Gurgaon, Gurgaon, Haryana  3 Floors  North-East
#
#      AGEPOSSESSION                                    NEARBYLOCATIONS  \
# 0  0 to 1 Year Old  ['Good Earth City Center 2', 'Kunskapsskolan I...
#
#                                          DESCRIPTION  \
# 0  Do you wish to buy an independent house in sec...
#
#                                       FURNISHDETAILS  \
# 0  ['1 Wardrobe', '1 Fan', '1 Exhaust Fan', '1 Ge...
#
# ...

# %%
data1['PRICE'] = data1['PRICE'].astype('float')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PROPERTY_NAME    1095 non-null   object
#  1   SOCIETY          1095 non-null   object
#  2   PRICE            958 non-null    float64
#  3   RATE             1054 non-null   object
#  4   AREA             1095 non-null   object
#  5   AREAWITHTYPE     987 non-null    object
#  6   BEDROOM          987 non-null    object
#  7   BATHROOM         987 non-null    object
#  8   BALCONY          987 non-null    object
#  9   ADDITIONALROOM   589 non-null    object
#  10  ADDRESS          1031 non-null   object
#  11  NOOFFLOOR        967 non-null    object
#  12  FACING           674 non-null    object
#  13  AGEPOSSESSION    987 non-null    object
#  14  NEARBYLOCATIONS  913 non-null    object
#  15  DESCRIPTION      1036 non-null   object
# ...

# %%
data1['RATE'].value_counts()
# Out:
# RATE
# ₹ 22,222/sq.ft.     14
# ₹ 11,111/sq.ft.     12
# ₹ 33,333/sq.ft.     11
# ₹ 10,000/sq.ft.     10
# ₹ 37,037/sq.ft.      7
# ₹ 13,333/sq.ft.      7
# ₹ 26,235/sq.ft.      6
# ₹ 26,667/sq.ft.      6
# ₹ 8,000/sq.ft.       6
# ₹ 31,481/sq.ft.      6
# ₹ 30,556/sq.ft.      6
# ₹ 23,333/sq.ft.      5
# ₹ 5,000/sq.ft.       5
# ₹ 9,444/sq.ft.       5
# ₹ 11,100/sq.ft.      5
# ₹ 8,889/sq.ft.       5
# ₹ 32,407/sq.ft.      5
# ₹ 23,148/sq.ft.      5
# ₹ 9,722/sq.ft.       4
# ₹ 35,000/sq.ft.      4
# ₹ 15,625/sq.ft.      4
# ₹ 21,605/sq.ft.      4
# ₹ 6,944/sq.ft.       4
# ₹ 18,889/sq.ft.      4
# ₹ 24,691/sq.ft.      4
# ₹ 25,000/sq.ft.      4
# ₹ 7,058/sq.ft.       4
# ₹ 34,722/sq.ft.      4
# ₹ 27,778/sq.ft.      4
# ₹ 100,000/sq.ft.     3
# ₹ 13,889/sq.ft.      3
# ₹ 24,500/sq.ft.      3
# ₹ 17,037/sq.ft.      3
# ₹ 10,556/sq.ft.      3
# ₹ 6,666/sq.ft.       3
# ₹ 9,259/sq.ft.       3
# ₹ 8,235/sq.ft.       3
# ₹ 44,444/sq.ft.      3
# ₹ 11,250/sq.ft.      3
# ...

# %%
data1['RATE'] = data1['RATE'].str.split("/").str.get(0).str.replace('₹'," ").str.replace(",","").str.replace(" ","").str.strip()

# %%
data1['RATE']
# Out:
# 0        20115
# 1       105751
# 2        38251
# 3        43066
# 4        53763
# 5        39062
# 6        37037
# 7        48889
# 8        38150
# 9        10077
# 10       32963
# 11       27778
# 12       34083
# 13       33200
# 14       30556
# 15       14914
# 16       29861
# 17       23333
# 18       41762
# 19       15451
# 20       12938
# 21       38095
# 22       25926
# 23       26235
# 24       38760
# 25       25926
# 26        9374
# 27       13410
# 28       21124
# 29       32593
# 30       24170
# 31       37037
# 32       28490
# 33      122222
# 34       13542
# 35       19097
# 36       48148
# 37       22222
# 38       22222
# 39       33333
# 40       32222
# 41        7290
# 42       27741
# 43       50000
# 44       43534
# 45       45889
# 46       34722
# 47         NaN
# 48       20690
# 49       29716
# 50       16378
# 51       17284
# 52       37777
# 53       12519
# 54       25562
# 55       27971
# 56       21000
# 57       24500
# ...

# %%
data1['RATE'] = data1['RATE'].astype('float')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PROPERTY_NAME    1095 non-null   object
#  1   SOCIETY          1095 non-null   object
#  2   PRICE            958 non-null    float64
#  3   RATE             1054 non-null   float64
#  4   AREA             1095 non-null   object
#  5   AREAWITHTYPE     987 non-null    object
#  6   BEDROOM          987 non-null    object
#  7   BATHROOM         987 non-null    object
#  8   BALCONY          987 non-null    object
#  9   ADDITIONALROOM   589 non-null    object
#  10  ADDRESS          1031 non-null   object
#  11  NOOFFLOOR        967 non-null    object
#  12  FACING           674 non-null    object
#  13  AGEPOSSESSION    987 non-null    object
#  14  NEARBYLOCATIONS  913 non-null    object
#  15  DESCRIPTION      1036 non-null   object
# ...

# %%
data1.rename(columns={'RATE':'PRICE_PER_SQFT'},inplace=True)

# %%
data1.sample(2)
# Out:
#                                          PROPERTY_NAME SOCIETY  PRICE  \
# 819  12 Bedroom House for sale in Mehrauli Gurgaon ...     nan   8.00
# 566          2 Bedroom House for sale in Manohar Nagar     nan   0.55
#
#      PRICE_PER_SQFT                     AREA  \
# 819         17707.0    (420 sq.m.) Plot Area
# 566          4583.0  (111 sq.m.) Carpet Area
#
#                          AREAWITHTYPE      BEDROOM     BATHROOM       BALCONY  \
# 819       Plot area 502(419.74 sq.m.)  12 Bedrooms  4 Bathrooms  3+ Balconies
# 566  Carpet area: 1200 (111.48 sq.m.)   2 Bedrooms  2 Bathrooms    No Balcony
#
#               ADDITIONALROOM  \
# 819  Servant Room,Store Room
# 566                      NaN
#
#                                                ADDRESS NOOFFLOOR      FACING  \
# 819            Mehrauli Gurgaon Road, Gurgaon, Haryana  3 Floors       North
# 566  Manohar Nagar, Gurgaon, Haryana, India, Manoha...  2 Floors  North-East
#
# ...

# %%
data1['BEDROOM'].value_counts()
# Out:
# BEDROOM
# 4 Bedrooms     240
# 5 Bedrooms     197
# 3 Bedrooms     151
# 2 Bedrooms      91
# 6 Bedrooms      82
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      34
# 7 Bedrooms      32
# 12 Bedrooms     29
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 18 Bedrooms      2
# 19 Bedrooms      2
# 11 Bedrooms      2
# 20 Bedrooms      1
# 21 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: count, dtype: int64

# %%
data1['BEDROOM'].isnull().sum()
# Out:
# 108

# %%
data1 = data1[~data1['BEDROOM'].isnull()]

# %%
data1['BEDROOM'].isnull().sum()
# Out:
# 0

# %%
data1.shape
# Out:
# (987, 19)

# %%
data1['BEDROOM'].value_counts()
# Out:
# BEDROOM
# 4 Bedrooms     240
# 5 Bedrooms     197
# 3 Bedrooms     151
# 2 Bedrooms      91
# 6 Bedrooms      82
# 9 Bedrooms      45
# 1 Bedroom       38
# 8 Bedrooms      34
# 7 Bedrooms      32
# 12 Bedrooms     29
# 10 Bedrooms     21
# 16 Bedrooms     12
# 13 Bedrooms      4
# 18 Bedrooms      2
# 19 Bedrooms      2
# 11 Bedrooms      2
# 20 Bedrooms      1
# 21 Bedrooms      1
# 36 Bedrooms      1
# 34 Bedrooms      1
# 14 Bedrooms      1
# Name: count, dtype: int64

# %%
data1['BEDROOM'] = data1['BEDROOM'].str.split(" ").str.get(0).str.strip()
# Out:
# <ipython-input-330-d9e2c8175437>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['BEDROOM'] = data1['BEDROOM'].str.split(" ").str.get(0).str.strip()

# %%
data1.sample(3)
# Out:
#                                      PROPERTY_NAME                 SOCIETY  \
# 404       8 Bedroom House for sale in Laxman Vihar                     nan
# 674        8 Bedroom House for sale in DLF Phase 3  dlf city plots phase 3
# 788  8 Bedroom House for sale in Sector 46 Gurgaon                     nan
#
#      PRICE  PRICE_PER_SQFT                   AREA  \
# 404   1.10          6111.0  (167 sq.m.) Plot Area
# 674   1.60         29629.0   (50 sq.m.) Plot Area
# 788   4.35         23693.0  (171 sq.m.) Plot Area
#
#                                           AREAWITHTYPE BEDROOM     BATHROOM  \
# 404                        Plot area 200(167.23 sq.m.)       8  4 Bathrooms
# 674  Plot area 540(50.17 sq.m.)Built Up area: 540 s...       8  5 Bathrooms
# 788                        Plot area 204(170.57 sq.m.)       8  8 Bathrooms
#
#           BALCONY         ADDITIONALROOM  \
# 404  3+ Balconies                    NaN
# 674  3+ Balconies                    NaN
# ...

# %%
data1['BATHROOM'].isnull().sum()
# Out:
# 0

# %%
data1['BATHROOM'].value_counts()
# Out:
# BATHROOM
# 4 Bathrooms     234
# 3 Bathrooms     167
# 5 Bathrooms     139
# 2 Bathrooms     118
# 6 Bathrooms      86
# 1 Bathroom       67
# 9 Bathrooms      42
# 7 Bathrooms      39
# 8 Bathrooms      30
# 12 Bathrooms     23
# 10 Bathrooms     11
# 16 Bathrooms      8
# 18 Bathrooms      4
# 13 Bathrooms      4
# 11 Bathrooms      4
# 20 Bathrooms      3
# 17 Bathrooms      3
# 14 Bathrooms      2
# 21 Bathrooms      1
# 36 Bathrooms      1
# 34 Bathrooms      1
# Name: count, dtype: int64

# %%
data1['BATHROOM'] = data1['BATHROOM'].str.split(" ").str.get(0).str.strip()

# %%
data1.sample(2)
# Out:
#                                       PROPERTY_NAME                 SOCIETY  \
# 742        12 Bedroom House for sale in DLF Phase 2  dlf city plots phase 2
# 1077  9 Bedroom House for sale in Sector 40 Gurgaon                     nan
#
#       PRICE  PRICE_PER_SQFT                   AREA  \
# 742    10.0        400000.0   (23 sq.m.) Plot Area
# 1077    5.0         21124.0  (220 sq.m.) Plot Area
#
#                     AREAWITHTYPE BEDROOM BATHROOM       BALCONY  \
# 742   Plot area 250(23.23 sq.m.)      12       12  3+ Balconies
# 1077  Plot area 263(219.9 sq.m.)       9        9  3+ Balconies
#
#                ADDITIONALROOM                                 ADDRESS  \
# 742   Study Room,Servant Room  Kkmb108, DLF Phase 2, Gurgaon, Haryana
# 1077               Pooja Room     Sector 40 Gurgaon, Gurgaon, Haryana
#
#      NOOFFLOOR      FACING    AGEPOSSESSION  \
# 742   4 Floors       North  1 to 5 Year Old
# 1077  3 Floors  South-East  1 to 5 Year Old
#
# ...

# %%
data1['BALCONY'].isnull().sum()
# Out:
# 0

# %%
data1['BALCONY'].value_counts()
# Out:
# BALCONY
# 3+ Balconies    374
# 2 Balconies     224
# 3 Balconies     163
# No Balcony      118
# 1 Balcony       108
# Name: count, dtype: int64

# %%
data1['BALCONY'] = data1['BALCONY'].str.split(" ").str.get(0).str.replace("No",'0').str.strip()

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 987 entries, 0 to 1090
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PROPERTY_NAME    987 non-null    object
#  1   SOCIETY          987 non-null    object
#  2   PRICE            958 non-null    float64
#  3   PRICE_PER_SQFT   958 non-null    float64
#  4   AREA             987 non-null    object
#  5   AREAWITHTYPE     987 non-null    object
#  6   BEDROOM          987 non-null    object
#  7   BATHROOM         987 non-null    object
#  8   BALCONY          987 non-null    object
#  9   ADDITIONALROOM   589 non-null    object
#  10  ADDRESS          982 non-null    object
#  11  NOOFFLOOR        967 non-null    object
#  12  FACING           674 non-null    object
#  13  AGEPOSSESSION    987 non-null    object
#  14  NEARBYLOCATIONS  864 non-null    object
#  15  DESCRIPTION      987 non-null    object
#  16  FURNISHDETAILS   743 non-null    object
# ...

# %%
data1['BEDROOM'] = data1['BEDROOM'].astype('int')
data1['BATHROOM'] = data1['BATHROOM'].astype('int')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 987 entries, 0 to 1090
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PROPERTY_NAME    987 non-null    object
#  1   SOCIETY          987 non-null    object
#  2   PRICE            958 non-null    float64
#  3   PRICE_PER_SQFT   958 non-null    float64
#  4   AREA             987 non-null    object
#  5   AREAWITHTYPE     987 non-null    object
#  6   BEDROOM          987 non-null    int64
#  7   BATHROOM         987 non-null    int64
#  8   BALCONY          987 non-null    object
#  9   ADDITIONALROOM   589 non-null    object
#  10  ADDRESS          982 non-null    object
#  11  NOOFFLOOR        967 non-null    object
#  12  FACING           674 non-null    object
#  13  AGEPOSSESSION    987 non-null    object
#  14  NEARBYLOCATIONS  864 non-null    object
#  15  DESCRIPTION      987 non-null    object
#  16  FURNISHDETAILS   743 non-null    object
# ...

# %%
data1['ADDITIONALROOM'].isnull().sum()
# Out:
# 398

# %%
data1['ADDITIONALROOM'].value_counts()
# Out:
# ADDITIONALROOM
# Servant Room                                     82
# Pooja Room,Study Room,Servant Room,Store Room    63
# Others                                           59
# Pooja Room                                       38
# Pooja Room,Study Room,Servant Room               34
# Pooja Room,Study Room,Servant Room,Others        32
# Store Room                                       31
# Pooja Room,Servant Room                          24
# Study Room                                       19
# Study Room,Servant Room                          19
# Servant Room,Store Room                          15
# Pooja Room,Study Room                            11
# Pooja Room,Store Room                            11
# Pooja Room,Others                                11
# Pooja Room,Store Room,Study Room,Servant Room     9
# Servant Room,Pooja Room                           8
# Servant Room,Others                               8
# Pooja Room,Servant Room,Store Room                7
# ...

# %%
data1.head()
# Out:
#                                       PROPERTY_NAME           SOCIETY  PRICE  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               nan   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               nan   3.00
#
#    PRICE_PER_SQFT                   AREA                 AREAWITHTYPE  \
# 0         20115.0  (242 sq.m.) Plot Area  Plot area 290(242.48 sq.m.)
# 1        105751.0   (50 sq.m.) Plot Area   Plot area 539(50.07 sq.m.)
# 2         38251.0   (51 sq.m.) Plot Area       Plot area 61(51 sq.m.)
# 3         43066.0  (108 sq.m.) Plot Area  Plot area 129(107.86 sq.m.)
# 4         53763.0   (52 sq.m.) Plot Area    Plot area 62(51.84 sq.m.)
#
#    BEDROOM  BATHROOM BALCONY                      ADDITIONALROOM  \
# ...

# %%
data1['ADDITIONALROOM'].fillna("not available",inplace=True)

# %%
data1['ADDITIONALROOM'].value_counts()
# Out:
# ADDITIONALROOM
# not available                                    398
# Servant Room                                      82
# Pooja Room,Study Room,Servant Room,Store Room     63
# Others                                            59
# Pooja Room                                        38
# Pooja Room,Study Room,Servant Room                34
# Pooja Room,Study Room,Servant Room,Others         32
# Store Room                                        31
# Pooja Room,Servant Room                           24
# Study Room,Servant Room                           19
# Study Room                                        19
# Servant Room,Store Room                           15
# Pooja Room,Store Room                             11
# Pooja Room,Study Room                             11
# Pooja Room,Others                                 11
# Pooja Room,Store Room,Study Room,Servant Room      9
# Servant Room,Pooja Room                            8
# ...

# %%
data1['ADDITIONALROOM']
# Out:
# 0                                        Servant Room
# 1                  Store Room,Pooja Room,Servant Room
# 2                                        Servant Room
# 3                                        Servant Room
# 4                                              Others
# 5                                        Servant Room
# 6                  Servant Room,Pooja Room,Store Room
# 7                                        Servant Room
# 8                                          Store Room
# 9                                        Servant Room
# 10                                         Store Room
# 11      Study Room,Servant Room,Pooja Room,Store Room
# 12                                         Pooja Room
# 13      Pooja Room,Study Room,Servant Room,Store Room
# 14      Study Room,Servant Room,Store Room,Pooja Room
# 15                              Pooja Room,Study Room
# 16                 Servant Room,Pooja Room,Store Room
# ...

# %%
data1['ADDITIONALROOM'] = data1['ADDITIONALROOM'].str.lower()

# %%
data1.sample(5)
# Out:
#                                          PROPERTY_NAME  \
# 758     12 Bedroom House for sale in Sector 46 Gurgaon
# 350  6 Bedroom House for sale in Ashok Vihar Phase ...
# 370         34 Bedroom House for sale in Manohar Nagar
# 294        1 Bedroom House for sale in Mianwali Colony
# 614           10 Bedroom House for sale in Rajiv Chowk
#
#                      SOCIETY  PRICE  PRICE_PER_SQFT  \
# 758                      nan    6.5         27461.0
# 350                      nan    1.5          5000.0
# 370            manohar nagar    5.6         12444.0
# 294  project mianwali colony    1.7          9444.0
# 614             hans enclave    2.0         10582.0
#
#                           AREA  \
# 758      (220 sq.m.) Plot Area
# 350  (279 sq.m.) Built-up Area
# 370      (418 sq.m.) Plot Area
# 294    (167 sq.m.) Carpet Area
# 614  (176 sq.m.) Built-up Area
#
#                                           AREAWITHTYPE  BEDROOM  BATHROOM  \
# ...

# %%
data1['NOOFFLOOR'].isnull().sum()
# Out:
# 20

# %%
data1['NOOFFLOOR'].value_counts()
# Out:
# NOOFFLOOR
# 3 Floors     309
# 2 Floors     300
# 1 Floors     183
# 4 Floors     139
# 5 Floors       9
# 0 Floors       6
# 14 Floors      3
# 6 Floors       3
# 11 Floors      2
# 12 Floors      2
# 10 Floors      2
# 16 Floors      1
# 51 Floors      1
# 41 Floors      1
# 27 Floors      1
# 20 Floors      1
# 13 Floors      1
# 21 Floors      1
# 02 Floors      1
# 33 Floors      1
# Name: count, dtype: int64

# %%
data1['NOOFFLOOR']
# Out:
# 0        3 Floors
# 1        2 Floors
# 2        5 Floors
# 3        5 Floors
# 4        5 Floors
# 5        4 Floors
# 6        3 Floors
# 7        4 Floors
# 8        3 Floors
# 9        4 Floors
# 10       2 Floors
# 11       3 Floors
# 12       4 Floors
# 13       3 Floors
# 14       3 Floors
# 15       3 Floors
# 16       3 Floors
# 17       3 Floors
# 18       3 Floors
# 19       3 Floors
# 20       3 Floors
# 21       3 Floors
# 22       2 Floors
# 23            NaN
# 24       4 Floors
# 25       3 Floors
# 26       1 Floors
# 27       3 Floors
# 28       3 Floors
# 29       3 Floors
# 30       2 Floors
# 31       3 Floors
# 32       3 Floors
# 33       1 Floors
# 34       2 Floors
# 35       3 Floors
# 36       4 Floors
# 37       1 Floors
# 38       3 Floors
# 39       3 Floors
# 40       2 Floors
# 41       1 Floors
# 42       4 Floors
# 43       4 Floors
# 44       4 Floors
# 45       4 Floors
# 46       2 Floors
# 47       3 Floors
# 48       3 Floors
# 49       2 Floors
# ...

# %%
data1['NOOFFLOOR'] = data1['NOOFFLOOR'].str.split(" ").str.get(0).str.strip()

# %%
data1['NOOFFLOOR'].fillna(0,inplace=True)

# %%
data1['NOOFFLOOR'] = data1['NOOFFLOOR'].astype('int32')

# %%
data1.rename(columns={"NOOFFLOOR":'FLOORNUM'},inplace=True)

# %%
data1.sample(3)
# Out:
#                                        PROPERTY_NAME SOCIETY  PRICE  \
# 1067  3 Bedroom House for sale in Sector 23A Gurgaon     nan   1.20
# 945    5 Bedroom House for sale in Sector 39 Gurgaon     nan  15.00
# 251    8 Bedroom House for sale in Sector 56 Gurgaon     nan   7.25
#
#       PRICE_PER_SQFT                   AREA  \
# 1067          6230.0  (179 sq.m.) Plot Area
# 945          33333.0  (418 sq.m.) Plot Area
# 251          29336.0  (253 sq.m.) Plot Area
#
#                                            AREAWITHTYPE  BEDROOM  BATHROOM  \
# 1067  Plot area 214(178.93 sq.m.)Built Up area: 1500...        3         2
# 945                         Plot area 500(418.06 sq.m.)        5         5
# 251                         Plot area 303(253.35 sq.m.)        8         8
#
#      BALCONY ADDITIONALROOM                                          ADDRESS  \
# 1067       2  not available  Sector 23, Sector 23A Gurgaon, Gurgaon, Haryana
# ...

# %%
data1['FACING']
# Out:
# 0       North-East
# 1              NaN
# 2             West
# 3            North
# 4             West
# 5             East
# 6             East
# 7              NaN
# 8       North-East
# 9             West
# 10            West
# 11           North
# 12           North
# 13           North
# 14            West
# 15            East
# 16      South-West
# 17      North-East
# 18           South
# 19           North
# 20            West
# 21      North-East
# 22             NaN
# 23            East
# 24            East
# 25      North-East
# 26      South-East
# 27      North-East
# 28      North-West
# 29             NaN
# 30            East
# 31           North
# 32            East
# 33      North-East
# 34             NaN
# 35      South-East
# 36      North-East
# 37           North
# 38            East
# 39           North
# 40           North
# 41            East
# 42      South-East
# 43      North-West
# 44            West
# 45      North-East
# 46            East
# ...

# %%
data1['FACING'].isnull().sum()
# Out:
# 313

# %%
data1['FACING'].value_counts()
# Out:
# FACING
# East          181
# North-East    159
# North         114
# West           75
# North-West     44
# South-East     40
# South          36
# South-West     25
# Name: count, dtype: int64

# %%
data1['FACING'].fillna('na',inplace=True)

# %%
data1['FACING'].value_counts()
# Out:
# FACING
# na            313
# East          181
# North-East    159
# North         114
# West           75
# North-West     44
# South-East     40
# South          36
# South-West     25
# Name: count, dtype: int64

# %%
data1['FACING'] = data1['FACING'].str.lower()

# %%
data1.columns
# Out:
# Index(['PROPERTY_NAME', 'SOCIETY', 'PRICE', 'PRICE_PER_SQFT', 'AREA',
#        'AREAWITHTYPE', 'BEDROOM', 'BATHROOM', 'BALCONY', 'ADDITIONALROOM',
#        'ADDRESS', 'FLOORNUM', 'FACING', 'AGEPOSSESSION', 'NEARBYLOCATIONS',
#        'DESCRIPTION', 'FURNISHDETAILS', 'FEATURES', 'RATING'],
#       dtype='object')

# %%
data1.insert(loc=4,column='AREA2',value=round((data1['PRICE']*10000000)/data1['PRICE_PER_SQFT']))

# %%
data1.sample(4)
# Out:
#                                           PROPERTY_NAME SOCIETY  PRICE  \
# 649   8 Bedroom House for sale in C Block Sushant Lo...   ansal   1.85
# 444                 3 Bedroom House for sale in Manesar     nan   2.00
# 1018       4 Bedroom House for sale in Sector 15 Part 2     nan   1.45
# 462     3 Bedroom House for sale in Ashok Vihar Phase 2     nan   1.00
#
#       PRICE_PER_SQFT   AREA2                   AREA  \
# 649         308333.0    60.0    (6 sq.m.) Plot Area
# 444          14954.0  1337.0  (124 sq.m.) Plot Area
# 1018         12393.0  1170.0  (109 sq.m.) Plot Area
# 462          11111.0   900.0   (84 sq.m.) Plot Area
#
#                                            AREAWITHTYPE  BEDROOM  BATHROOM  \
# 649                            Plot area 60(5.57 sq.m.)        8         8
# 444                      Plot area 1337.4(124.25 sq.m.)        3         1
# 1018  Plot area 130(108.7 sq.m.)Built Up area: 130 s...        4         4
# ...

# %%
data1.drop(columns='AREA',inplace=True)

# %%
data1.sample(2)
# Out:
#                                       PROPERTY_NAME  \
# 721  5 Bedroom House for sale in Sector 109 Gurgaon
# 704   6 Bedroom House for sale in Sector 51 Gurgaon
#
#                                  SOCIETY  PRICE  PRICE_PER_SQFT   AREA2  \
# 721  international city by sobha phase 2   9.50         26389.0  3600.0
# 704                                  nan   2.25         25000.0   900.0
#
#                     AREAWITHTYPE  BEDROOM  BATHROOM BALCONY  \
# 721  Plot area 400(334.45 sq.m.)        5         5      3+
# 704   Plot area 100(83.61 sq.m.)        6         3      3+
#
#                                     ADDITIONALROOM  \
# 721  pooja room,study room,store room,servant room
# 704                                  not available
#
#                                   ADDRESS  FLOORNUM      FACING  \
# 721  Sector 109 Gurgaon, Gurgaon, Haryana         2       south
# 704   Sector 51 Gurgaon, Gurgaon, Haryana         3  north-west
#
# ...

# %%
data1.rename(columns={'AREA2':'AREA'},inplace=True)

# %%
data1.head()
# Out:
#                                       PROPERTY_NAME           SOCIETY  PRICE  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon  bptp visionnaire   5.25
# 1  5 Bedroom House for sale in Sector 21A Faridabad               nan   5.70
# 2  10 Bedroom House for sale in Sushant Lok Phase 1               nan   2.10
# 3    21 Bedroom House for sale in Sector 54 Gurgaon               nan   5.00
# 4  12 Bedroom House for sale in Sushant Lok Phase 1               nan   3.00
#
#    PRICE_PER_SQFT    AREA                 AREAWITHTYPE  BEDROOM  BATHROOM  \
# 0         20115.0  2610.0  Plot area 290(242.48 sq.m.)        5         4
# 1        105751.0   539.0   Plot area 539(50.07 sq.m.)        5         4
# 2         38251.0   549.0       Plot area 61(51 sq.m.)       10        10
# 3         43066.0  1161.0  Plot area 129(107.86 sq.m.)       21        21
# 4         53763.0   558.0    Plot area 62(51.84 sq.m.)       12        12
#
#   BALCONY                      ADDITIONALROOM  \
# ...

# %%
data1.insert(loc=1,column='PROPERTY_TYPE',value='houses')

# %%
data1.head()
# Out:
#                                       PROPERTY_NAME PROPERTY_TYPE  \
# 0    5 Bedroom House for sale in Sector 70A Gurgaon        houses
# 1  5 Bedroom House for sale in Sector 21A Faridabad        houses
# 2  10 Bedroom House for sale in Sushant Lok Phase 1        houses
# 3    21 Bedroom House for sale in Sector 54 Gurgaon        houses
# 4  12 Bedroom House for sale in Sushant Lok Phase 1        houses
#
#             SOCIETY  PRICE  PRICE_PER_SQFT    AREA  \
# 0  bptp visionnaire   5.25         20115.0  2610.0
# 1               nan   5.70        105751.0   539.0
# 2               nan   2.10         38251.0   549.0
# 3               nan   5.00         43066.0  1161.0
# 4               nan   3.00         53763.0   558.0
#
#                   AREAWITHTYPE  BEDROOM  BATHROOM BALCONY  \
# 0  Plot area 290(242.48 sq.m.)        5         4      3+
# 1   Plot area 539(50.07 sq.m.)        5         4       2
# 2       Plot area 61(51 sq.m.)       10        10      3+
# ...
