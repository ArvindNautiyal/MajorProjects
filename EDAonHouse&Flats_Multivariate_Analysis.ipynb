# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/feature_engineering_2.main.csv')

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
df.shape
# Out:
# (3803, 23)

# %% [markdown]
# Propertye Type Vs Price

# %%
sns.barplot(data=df,x=df['property_type'],y=df['price'],estimator='median',color='skyblue');

# %%
sns.boxplot(data=df,x=df['property_type'],y=df['price'],color='lightgreen');

# %% [markdown]
# Property Type vs Built up Area

# %%
sns.barplot(data=df,x=df['built_up_area'],y=df['property_type'],estimator='median')
# Out:
# <Axes: xlabel='built_up_area', ylabel='property_type'>

# %%
sns.boxplot(data=df,x=df['property_type'],y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
df['built_up_area'].max()
# Out:
# 737147.0

# %%
df = df[df['built_up_area']!=737147]

# %%
sns.boxplot(data=df,x=df['property_type'],y=df['built_up_area'],color='skyblue')
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# Property Type vs Price Per Sqft

# %%
sns.barplot(data=df,x=df['property_type'],y=df['price_per_sqft'],estimator='median')
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(data=df,x=df['property_type'],y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
df['price_per_sqft'].max()
# Out:
# 600000.0

# %%
df = df[df['price_per_sqft']!=600000]

# %%
sns.boxplot(data=df,x=df['property_type'],y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %% [markdown]
# Property_type vs Bedroom

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %% [markdown]
# Floor Num vs Property_type

# %%
sns.barplot(data=df,x=df['property_type'],y=df['floorNum'],color='lightgreen')
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(data=df,x=df['property_type'],y=df['floorNum'],color='skyblue')
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %% [markdown]
# Property Type & Age Possession

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(data=df,index='property_type',columns='agePossession',values='price',aggfunc='mean'),annot=True);

# %% [markdown]
# Property Type vs Furnishing

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(data=df,index='property_type',columns='furnishing_type',values='price',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %% [markdown]
# Property Type vs Luxury Score

# %%
sns.barplot(data=df,x=df['property_type'],y=df['luxury_score'],estimator='median')
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
l = []
for i in df.columns:
  l.append(i.lower().strip())

# %%
df.columns = l

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'floornum', 'facing',
#        'agepossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
df.rename(columns={'study room':'study_room','servant room':'servant_room','store room':"store_room",'pooja room':'pooja_room'},inplace=True)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areawithtype', 'bedroom', 'bathroom', 'balcony', 'floornum', 'facing',
#        'agepossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study_room', 'servant_room', 'store_room', 'pooja_room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %% [markdown]
# Property_type vs Sector

# %%
plt.figure(figsize=(14,7))
sns.heatmap(pd.crosstab(df['property_type'],df['sector']))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
df['sector']
# Out:
# 0        sector 36
# 1        sector 89
# 2        sector 86
# 3       sohna road
# 4        sector 92
#            ...
# 3798     sector 84
# 3799    sector 109
# 3800      sector 2
# 3801     sector 43
# 3802     sector 68
# Name: sector, Length: 3801, dtype: object

# %%
df1 = df.groupby('sector')['price'].mean().reset_index()

# %%
df1.sample(2)
# Out:
#        sector     price
# 95  sector 89  1.117031
# 54  sector 53  5.782857

# %%
import re
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')

df1['sector_number'] = df1['sector'].apply(extract_sector_number)
df1_sorted = df1.sort_values(by='sector_number')

# %%
df1_sorted
# Out:
#                 sector     price  sector_number
# 3             sector 1  1.860000            1.0
# 23            sector 2  2.404921            2.0
# 32            sector 3  0.971250            3.0
# 41            sector 4  1.135000            4.0
# 50            sector 5  0.989231            5.0
# ..                 ...       ...            ...
# 17          sector 113  2.465814          113.0
# 0    dwarka expressway  1.372500            inf
# 1          gwal pahari  3.192222            inf
# 2              manesar  0.961515            inf
# 103         sohna road  0.683046            inf
#
# [104 rows x 3 columns]

# %%
plt.figure(figsize=(5, 25))
sns.heatmap(df1_sorted.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

luxury_score_sector = luxury_score.sort_values(by='sector_number')

plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# Price vs Area

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df,x=df['price'],y=df[df['area']<10000]['area'])
# Out:
# <Axes: xlabel='price', ylabel='area'>

# %%
fig , ax = plt.subplots(figsize=(14,8))
sns.scatterplot(data=df,x=df['price'],y=df[df['area']<10000]['area'],hue=df['agepossession'])
# Out:
# <Axes: xlabel='price', ylabel='area'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data= df , y = df[df['area']<10000]['area'],x = df['price'],hue=df['furnishing_type'].astype('category'))
# Out:
# <Axes: xlabel='price', ylabel='area'>

# %%
sns.barplot(data=df,x=df['bedroom'],y=df['price'],estimator=np.median,palette="tab10");
# Out:
# <ipython-input-159-e610e7e17046>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x=df['bedroom'],y=df['price'],estimator=np.median,palette="tab10");

# %%
sns.barplot(data=df,x=df['bathroom'],y=df['price'],estimator=np.median,palette="tab10");
# Out:
# <ipython-input-160-4a87bf4ba80b>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x=df['bathroom'],y=df['price'],estimator=np.median,palette="tab10");

# %%
sns.barplot(data=df,x=df['balcony'],y=df['price'],estimator=np.median,palette="tab10");
# Out:
# <ipython-input-161-e2664c67a1c5>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x=df['balcony'],y=df['price'],estimator=np.median,palette="tab10");

# %%
sns.barplot(data=df,x=df['agepossession'],y=df['price'],estimator=np.median,palette="tab10");
plt.xticks(rotation='vertical');
# Out:
# <ipython-input-164-5e367160acbf>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df,x=df['agepossession'],y=df['price'],estimator=np.median,palette="tab10");

# %%
sns.barplot(x=df['furnishing_type'],y=df['price'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price'>

# %%
sns.scatterplot(data = df ,x = df['luxury_score'],y= df['price'])
# Out:
# <Axes: xlabel='luxury_score', ylabel='price'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3801 entries, 0 to 3802
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3801 non-null   object
#  1   society              3800 non-null   object
#  2   sector               3801 non-null   object
#  3   price                3783 non-null   float64
#  4   price_per_sqft       3783 non-null   float64
#  5   area                 3783 non-null   float64
#  6   areawithtype         3801 non-null   object
#  7   bedroom              3801 non-null   int64
#  8   bathroom             3801 non-null   int64
#  9   balcony              3801 non-null   object
#  10  floornum             3782 non-null   float64
#  11  facing               2697 non-null   object
#  12  agepossession        3801 non-null   object
#  13  super_built_up_area  1915 non-null   float64
#  14  built_up_area        1731 non-null   float64
#  15  carpet_area          1944 non-null   float64
#  16  study_room           3801 non-null   int64
#  17  servant_room         3801 non-null   int64
#  18  store_room           3801 non-null   int64
#  19  pooja_room           3801 non-null   int64
#  20  others               3801 non-null   int64
#  21  furnishing_type      3801 non-null   int64
#  22  luxury_score         3801 non-null   int64
# dtypes: float64(7), int64(9), object(7)
# memory usage: 841.7+ KB

# %%
df3 = df.select_dtypes(include=['int', 'float'])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3801 entries, 0 to 3802
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   price                3783 non-null   float64
#  1   price_per_sqft       3783 non-null   float64
#  2   area                 3783 non-null   float64
#  3   bedroom              3801 non-null   int64
#  4   bathroom             3801 non-null   int64
#  5   floornum             3782 non-null   float64
#  6   super_built_up_area  1915 non-null   float64
#  7   built_up_area        1731 non-null   float64
#  8   carpet_area          1944 non-null   float64
#  9   study_room           3801 non-null   int64
#  10  servant_room         3801 non-null   int64
#  11  store_room           3801 non-null   int64
#  12  pooja_room           3801 non-null   int64
#  13  others               3801 non-null   int64
#  14  furnishing_type      3801 non-null   int64
#  15  luxury_score         3801 non-null   int64
# dtypes: float64(7), int64(9)
# memory usage: 633.9 KB

# %%
sns.heatmap(df3.corr())
# Out:
# <Axes: >
